# %% [markdown]
# # 3 Pre-processing & Training: Breast Cancer Gene Expressions <a id='3_modeling'></a>

# %% [markdown]
# ## 3.1 Contents <a id='3.1_contents'></a>

# %% [markdown]
# * [3 Preprocessing & Modeling](#3_modeling)
#     * [3.1 Contents](#2.1_contents)
#     * [3.2 Introduction](#3.2_intro)
#     * [3.3 Imports](#3.3_imports)
#     * [3.4 Loading the Data](#3.4_loading)
#     * [3.5 PCA](#3.5_pca)
#     * [3.6 Initial model: Logistic Regression](#3.6_initial_model)
#
#         * [3.6.1 Logistic Regression](#3.6.1_lr)
#         * [3.6.2 Performance Metrics](#3.6.2_metrics)
#     * [3.7 Exporting](#3.7_export)
#     * [3.7 Summary & Next Steps](#3.7_summary)

# %% [markdown]
# ## 3.2 Introduction <a id='3.2_intro'></a>
#
# Up until this point, I have cleaned, wrangled, and done ETA on my dataset of breast cancer gene expressions. In this notebook I will do pre-processing and initial model development. As a part of the pre-processing, I will do PCA in two ways: 1) for 190 components, which means that there will be more than 10 times as many rows as columns, to avoid issues related to being 'wide and short', and 2) for ~360 components, which covers 90% of the variance in the data. I will then do a preliminatry logistic regression model to use as a baseline, and run this model on the data with 190 components, with ~360 components, and with the full dataset.

# %% [markdown]
# ## 3.3 Imports  <a id='3.3_imports'></a>

# %%
import pyarrow.parquet as pq

# %matplotlib inline
#
# data manipulation and math
#
import numpy as np
import scipy as sp
import pandas as pd
#
# plotting and visualization
#
import matplotlib as mpl
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
#
import seaborn as sns
#
# modeling
#
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder as OHE
import sklearn.model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
#

import pickle

print("Loaded Libraries")
# Out:
# Loaded Libraries

# %% [markdown]
# ## Set Options

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
#
plt.rcParams['figure.figsize'] = (3, 3)
plt.style.use('seaborn-pastel')
plt.rcParams['figure.dpi'] = 150      
#
c0 = sns.color_palette()[0]
c1 = sns.color_palette()[1]
c2 = sns.color_palette()[2]
#
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

# %%
def points_plot(ax, Xtr, Xte, ytr, yte, 
                clf, 
                mesh = True, colorscale = cmap_light, cdiscrete = cmap_bold, 
                alpha = 0.1, psize = 10, 
                zfunc = False, predicted = False):
#
# note: this function only works for X.shape = (:, 2)
# it is intended to illustrate the classifier boundary
#
# get the column names if they exist to apply
# to the meshed data generated below
#
    try:
        feature_names = Xtr.columns
    except:
        feature_names = None
#        
    Xtrain = np.array(Xtr)
    Xtest = np.array(Xte)
#
    h = 0.02
#
# create a uniform grid spanning the range of the X values
# note that y here is NOT the target, it is the 2nd
# dimension of the desired plot
#
    X = np.concatenate((Xtrain, Xtest))
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                         np.linspace(y_min, y_max, 100))
#
# predict the target value at each point in the grid
#
# this method uses the probabilities from the classifier
# and applies a function to determine the class
#
    if zfunc:
        mesh_data = np.c_[xx.ravel(), yy.ravel()]
        if feature_names is not None:
            mesh_data = pd.DataFrame(mesh_data, 
                         columns = feature_names)
        p0 = clf.predict_proba(mesh_data)[:, 0]
        p1 = clf.predict_proba(mesh_data)[:, 1]
        Z = zfunc(p0, p1)
#
# this method uses the classifier to predict the classes directly
#
    else:
        mesh_data = np.c_[xx.ravel(), yy.ravel()]
        if feature_names is not None:
            mesh_data = pd.DataFrame(mesh_data, 
                                     columns = feature_names)
        Z = clf.predict(mesh_data)
    ZZ = Z.reshape(xx.shape)
#
# plt.pcolormesh() creates a shaded result over the grid
#
    if mesh:
        plt.pcolormesh(xx, yy, ZZ, 
                       cmap = cmap_light, 
                       alpha = alpha, 
                       axes = ax, 
                       shading = 'auto')
#
# add the points to the plot
# these can be the original target values
# or the predicted values
#
    if predicted:
        showtr = clf.predict(Xtr)
        showte = clf.predict(Xte)
    else:
        showtr = ytr
        showte = yte
#
# plot training points
#
    ax.scatter(Xtrain[:, 0], Xtrain[:, 1], 
               c = showtr - 1, 
               cmap = cmap_bold, 
               s = psize, 
               alpha = alpha, 
               edgecolor = "k")
#    
# plot testing points
#
    ax.scatter(Xtest[:, 0], Xtest[:, 1],
               c = showte - 1, 
               cmap = cmap_bold, 
               s = psize + 10,
               alpha = alpha, 
               marker = "s")
    ax.set_xlim(xx.min(), xx.max())
    ax.set_ylim(yy.min(), yy.max())
#
    return ax, xx, yy

# %% [markdown]
# ## 3.4 Loading the Data <a id='3.4_loading'></a>

# %%
# importing using parquet to preserve data types

num_data=pd.read_parquet(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\num_data.parquet', engine='pyarrow')

# %%
num_data.head()
# Out:
#             age_at_diagnosis  lymph_nodes_examined_positive  mutation_count  \
# patient_id
# 0                      75.65                             10               0
# 2                      43.19                              0               2
# 5                      48.87                              1               2
# 6                      47.68                              3               1
# 8                      76.97                              8               2
#
#             nottingham_prognostic_index  overall_survival_months  tumor_size  \
# patient_id
# 0                                 6.044                    140.5        22.0
# 2                                 4.020                     84.6        10.0
# 5                                 4.030                    163.7        15.0
# 6                                 4.050                    164.9        25.0
# 8                                 6.080                     41.4        40.0
#
#             type_of_breast_surgery_BREAST CONSERVING  \
# patient_id
# 0                                                  0
# 2                                                  1
# 5                                                  0
# 6                                                  0
# 8                                                  0
#
#             type_of_breast_surgery_MASTECTOMY  type_of_breast_surgery_nan  \
# patient_id
# 0                                           1                           0
# 2                                           0                           0
# 5                                           1                           0
# 6                                           1                           0
# 8                                           1                           0
#
#             cancer_type_Breast Cancer  cancer_type_Breast Sarcoma  \
# patient_id
# 0                                   1                           0
# 2                                   1                           0
# 5                                   1                           0
# 6                                   1                           0
# 8                                   1                           0
#
#             cancer_type_detailed_Breast  \
# patient_id
# 0                                     0
# 2                                     0
# 5                                     0
# 6                                     0
# 8                                     0
#
#             cancer_type_detailed_Breast Invasive Ductal Carcinoma  \
# patient_id
# 0                                                               1
# 2                                                               1
# 5                                                               1
# 6                                                               0
# 8                                                               0
#
#             cancer_type_detailed_Breast Invasive Lobular Carcinoma  \
# patient_id
# 0                                                                0
# 2                                                                0
# 5                                                                0
# 6                                                                0
# 8                                                                0
#
#             cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma  \
# patient_id
# 0                                                                       0
# 2                                                                       0
# 5                                                                       0
# 6                                                                       0
# 8                                                                       0
#
#             cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  \
# patient_id
# 0                                                                        0
# 2                                                                        0
# 5                                                                        0
# 6                                                                        1
# 8                                                                        1
#
#             cancer_type_detailed_Metaplastic Breast Cancer  \
# patient_id
# 0                                                        0
# 2                                                        0
# 5                                                        0
# 6                                                        0
# 8                                                        0
#
#             cancer_type_detailed_nan  cellularity_High  cellularity_Low  \
# patient_id
# 0                                  0                 0                0
# 2                                  0                 1                0
# 5                                  0                 1                0
# 6                                  0                 0                0
# 8                                  0                 1                0
#
#             cellularity_Moderate  cellularity_nan  chemotherapy_0  \
# patient_id
# 0                              0                1               1
# 2                              0                0               1
# 5                              0                0               0
# 6                              1                0               0
# 8                              0                0               0
#
#             chemotherapy_1  pam50_+_claudin-low_subtype_Basal  \
# patient_id
# 0                        0                                  0
# 2                        0                                  0
# 5                        1                                  0
# 6                        1                                  0
# 8                        1                                  0
#
#             pam50_+_claudin-low_subtype_Her2  \
# patient_id
# 0                                          0
# 2                                          0
# 5                                          0
# 6                                          0
# 8                                          0
#
#             pam50_+_claudin-low_subtype_LumA  \
# patient_id
# 0                                          0
# 2                                          1
# 5                                          0
# 6                                          0
# 8                                          0
#
#             pam50_+_claudin-low_subtype_LumB  pam50_+_claudin-low_subtype_NC  \
# patient_id
# 0                                          0                               0
# 2                                          0                               0
# 5                                          1                               0
# 6                                          1                               0
# 8                                          1                               0
#
#             pam50_+_claudin-low_subtype_Normal  \
# patient_id
# 0                                            0
# 2                                            0
# 5                                            0
# 6                                            0
# 8                                            0
#
#             pam50_+_claudin-low_subtype_claudin-low  cohort_1  cohort_2  \
# patient_id
# 0                                                 1         1         0
# 2                                                 0         1         0
# 5                                                 0         1         0
# 6                                                 0         1         0
# 8                                                 0         1         0
#
#             cohort_3  cohort_4  cohort_5  er_status_measured_by_ihc_Negative  \
# patient_id
# 0                  0         0         0                                   0
# 2                  0         0         0                                   0
# 5                  0         0         0                                   0
# 6                  0         0         0                                   0
# 8                  0         0         0                                   0
#
#             er_status_measured_by_ihc_Positive  er_status_measured_by_ihc_nan  \
# patient_id
# 0                                            1                              0
# 2                                            1                              0
# 5                                            1                              0
# 6                                            1                              0
# 8                                            1                              0
#
#             er_status_Negative  er_status_Positive  \
# patient_id
# 0                            0                   1
# 2                            0                   1
# 5                            0                   1
# 6                            0                   1
# 8                            0                   1
#
#             neoplasm_histologic_grade_1.0  neoplasm_histologic_grade_2.0  \
# patient_id
# 0                                       0                              0
# 2                                       0                              0
# 5                                       0                              1
# 6                                       0                              1
# 8                                       0                              0
#
#             neoplasm_histologic_grade_3.0  neoplasm_histologic_grade_nan  \
# patient_id
# 0                                       1                              0
# 2                                       1                              0
# 5                                       0                              0
# 6                                       0                              0
# 8                                       1                              0
#
#             her2_status_measured_by_snp6_GAIN  \
# patient_id
# 0                                           0
# 2                                           0
# 5                                           0
# 6                                           0
# 8                                           0
#
#             her2_status_measured_by_snp6_LOSS  \
# patient_id
# 0                                           0
# 2                                           0
# 5                                           0
# 6                                           0
# 8                                           0
#
#             her2_status_measured_by_snp6_NEUTRAL  \
# patient_id
# 0                                              1
# 2                                              1
# 5                                              1
# 6                                              1
# 8                                              1
#
#             her2_status_measured_by_snp6_UNDEF  her2_status_Negative  \
# patient_id
# 0                                            0                     1
# 2                                            0                     1
# 5                                            0                     1
# 6                                            0                     1
# 8                                            0                     1
#
#             her2_status_Positive  tumor_other_histologic_subtype_Ductal/NST  \
# patient_id
# 0                              0                                          1
# 2                              0                                          1
# 5                              0                                          1
# 6                              0                                          0
# 8                              0                                          0
#
#             tumor_other_histologic_subtype_Lobular  \
# patient_id
# 0                                                0
# 2                                                0
# 5                                                0
# 6                                                0
# 8                                                0
#
#             tumor_other_histologic_subtype_Medullary  \
# patient_id
# 0                                                  0
# 2                                                  0
# 5                                                  0
# 6                                                  0
# 8                                                  0
#
#             tumor_other_histologic_subtype_Metaplastic  \
# patient_id
# 0                                                    0
# 2                                                    0
# 5                                                    0
# 6                                                    0
# 8                                                    0
#
#             tumor_other_histologic_subtype_Mixed  \
# patient_id
# 0                                              0
# 2                                              0
# 5                                              0
# 6                                              1
# 8                                              1
#
#             tumor_other_histologic_subtype_Mucinous  \
# patient_id
# 0                                                 0
# 2                                                 0
# 5                                                 0
# 6                                                 0
# 8                                                 0
#
#             tumor_other_histologic_subtype_Other  \
# patient_id
# 0                                              0
# 2                                              0
# 5                                              0
# 6                                              0
# 8                                              0
#
#             tumor_other_histologic_subtype_Tubular/ cribriform  \
# patient_id
# 0                                                            0
# 2                                                            0
# 5                                                            0
# 6                                                            0
# 8                                                            0
#
#             tumor_other_histologic_subtype_nan  hormone_therapy_0  \
# patient_id
# 0                                            0                  0
# 2                                            0                  0
# 5                                            0                  0
# 6                                            0                  0
# 8                                            0                  0
#
#             hormone_therapy_1  inferred_menopausal_state_Post  \
# patient_id
# 0                           1                               1
# 2                           1                               0
# 5                           1                               0
# 6                           1                               0
# 8                           1                               1
#
#             inferred_menopausal_state_Pre  primary_tumor_laterality_Left  \
# patient_id
# 0                                       0                              0
# 2                                       1                              0
# 5                                       1                              0
# 6                                       1                              0
# 8                                       0                              0
#
#             primary_tumor_laterality_Right  primary_tumor_laterality_nan  \
# patient_id
# 0                                        1                             0
# 2                                        1                             0
# 5                                        1                             0
# 6                                        1                             0
# 8                                        1                             0
#
#             oncotree_code_BREAST  oncotree_code_IDC  oncotree_code_ILC  \
# patient_id
# 0                              0                  1                  0
# 2                              0                  1                  0
# 5                              0                  1                  0
# 6                              0                  0                  0
# 8                              0                  0                  0
#
#             oncotree_code_IMMC  oncotree_code_MBC  oncotree_code_MDLC  \
# patient_id
# 0                            0                  0                   0
# 2                            0                  0                   0
# 5                            0                  0                   0
# 6                            0                  0                   1
# 8                            0                  0                   1
#
#             oncotree_code_nan  overall_survival_0  overall_survival_1  \
# patient_id
# 0                           0                   0                   1
# 2                           0                   0                   1
# 5                           0                   1                   0
# 6                           0                   0                   1
# 8                           0                   1                   0
#
#             pr_status_Negative  pr_status_Positive  radio_therapy_0  \
# patient_id
# 0                            1                   0                0
# 2                            0                   1                0
# 5                            0                   1                1
# 6                            0                   1                0
# 8                            0                   1                0
#
#             radio_therapy_1  3-gene_classifier_subtype_ER+/HER2- High Prolif  \
# patient_id
# 0                         1                                                0
# 2                         1                                                1
# 5                         0                                                0
# 6                         1                                                0
# 8                         1                                                1
#
#             3-gene_classifier_subtype_ER+/HER2- Low Prolif  \
# patient_id
# 0                                                        0
# 2                                                        0
# 5                                                        0
# 6                                                        0
# 8                                                        0
#
#             3-gene_classifier_subtype_ER-/HER2-  \
# patient_id
# 0                                             1
# 2                                             0
# 5                                             0
# 6                                             0
# 8                                             0
#
#             3-gene_classifier_subtype_HER2+  3-gene_classifier_subtype_nan  \
# patient_id
# 0                                         0                              0
# 2                                         0                              0
# 5                                         0                              1
# 6                                         0                              1
# 8                                         0                              0
#
#             tumor_stage_0.0  tumor_stage_1.0  tumor_stage_2.0  \
# patient_id
# 0                         0                0                1
# 2                         0                1                0
# 5                         0                0                1
# 6                         0                0                1
# 8                         0                0                1
#
#             tumor_stage_3.0  tumor_stage_4.0  tumor_stage_nan  \
# patient_id
# 0                         0                0                0
# 2                         0                0                0
# 5                         0                0                0
# 6                         0                0                0
# 8                         0                0                0
#
#             death_from_cancer_0  death_from_cancer_1   brca2   palb2    pten  \
# patient_id
# 0                             0                    1 -0.5738 -1.6217  1.4524
# 2                             0                    1  0.2777 -1.2154  0.5296
# 5                             1                    0 -0.8426  0.2114 -0.3326
# 6                             0                    1 -0.5428 -1.6592  0.6369
# 8                             1                    0 -0.9039 -0.7219  0.2168
#
#               tp53     atm    cdh1   chek2     nbn     nf1   stk11   bard1  \
# patient_id
# 0           0.3504  1.1517  0.0348  0.1266 -0.8361 -0.8578 -0.4294 -1.1201
# 2          -0.0136 -0.2659  1.3594  0.7961  0.5419 -2.6059  0.5120  0.4390
# 5           0.5141 -0.0803  1.1398  0.4187 -0.4030 -1.1305  0.2362 -0.1721
# 6           1.6708 -0.8880  1.2491 -1.1889 -0.4174 -0.6165  1.0078 -0.4010
# 8           0.3484  0.3897  0.9131  0.9356  0.7675 -0.2940 -0.2961  0.6320
#
#               mlh1    msh2    msh6    pms2   epcam  rad51c  rad51d   rad50  \
# patient_id
# 0          -0.4844 -0.7483 -1.6660 -0.1250 -0.3721 -0.6508 -0.1278  1.7330
# 2           1.2266  0.7612  0.1821  1.0104  0.5600 -0.4018 -0.2909  0.7440
# 5          -1.7910  3.0955  0.6608  2.6127  2.5553 -0.0391 -0.4421  1.4528
# 6          -1.3905  4.8798  0.0615  2.9414  4.1161 -0.3098 -1.3470  1.2102
# 8          -0.3582  0.3032  0.8747  0.6323  0.3349 -0.2652 -0.1541 -0.7631
#               dab2  diras3   dlec1    dph1    egfr   eif4e  eif4ebp1  eif5a2  \
# patient_id
# 0           1.2766  0.2883 -0.4517  1.1179  2.0696 -0.2314   -0.2265  0.5513
# 2          -1.7476  0.6600  0.4479  1.6732 -0.3609  0.9246   -0.3173 -0.5307
# 5          -0.7936 -0.1572 -0.6188  0.2521 -0.0991  3.1838   -0.5358  0.2586
# 6           0.1723  0.2875 -0.7166  1.4561 -0.7250  2.9343   -0.2353  0.4649
# 8          -0.3024 -0.5542  0.0629  1.3411 -0.5042  0.4861    1.2588 -1.0460
#
#              erbb2   erbb3   erbb4     fas    fgf1   fgfr1   folr1   folr2  \
# patient_id
# 0          -1.0548 -1.7207  0.2415 -0.1829  2.2525  1.7000  1.6797  1.0893
# 2          -0.7633  0.5803  0.0059 -0.4012 -0.8545  0.3062 -0.7914 -0.9169
# 5          -0.7661 -1.3607 -0.4383  2.1470  0.9773 -0.4567 -0.4299  0.5313
# 6          -0.3172 -0.6405 -0.5122  1.8836  0.4925 -0.7820 -0.5803  1.3413
# 8          -0.5962  1.4865 -1.0922  0.5010 -1.0715  0.8701  0.5115  0.6556
#
#              folr3   foxo1   foxo3   gdf11    gdf2   gsk3b   hif1a   hla-g  \
# patient_id
# 0           0.4606  2.5507  0.9213 -0.6499 -1.5386 -0.7982  0.4191  0.1048
# 2          -0.0141 -0.7180 -1.6144  0.0169  1.9384 -0.0094 -0.8038 -0.9355
# 5           0.3959 -0.4464 -1.2823 -1.2771  0.5162 -1.7768  3.5336  1.9768
# 6           0.6259  0.4124 -1.2511 -0.9396 -2.8998 -1.6895  3.3403  2.0772
# 8           0.3455 -1.1731 -1.5713 -0.3794  0.5430 -0.3001  1.3211  0.0246
#
#               hras    igf1   igf1r    inha   inhba   inhbc   itgav   itgb3  \
# patient_id
# 0          -0.9923  0.9947 -0.4445  0.0883  1.1190 -0.4613 -0.4337 -0.2304
# 2           0.9679  0.8191  0.0638 -0.2797 -0.6347 -0.2217 -0.7036  0.2577
# 5          -0.6058  1.5676 -0.6426 -0.4539 -0.3512 -1.4372  2.2121  0.6469
# 6           0.9831  2.8491 -0.7844  1.9837  0.6968  0.1198  1.3652 -0.8502
# 8           0.2881 -0.2109 -0.5785 -0.1702 -0.5076  0.3660 -1.2198 -0.3194
#
#             izumo1r     kdr     kit    kras  map2k1  map2k2  map2k3  map2k4  \
# patient_id
# 0            0.7302  2.7183  2.9336 -2.1663  0.4229 -0.0078  2.6548 -0.0279
# 2           -0.9707 -0.9864 -0.4866 -0.6278 -2.0640 -0.5408 -1.9500 -1.1421
# 5           -1.1507 -0.4649  0.4321  0.5189  0.0169 -0.8582 -2.2248  0.6299
# 6           -0.8229 -1.2923 -0.5447  0.5582 -0.2496 -1.4272 -0.0413  1.0026
# 8            1.0331 -1.7323 -0.1758 -0.6360  0.4079 -2.2363 -0.1867 -0.3795
#
#             map2k5  map3k1  map3k3  map3k4  map3k5   mapk1  mapk12  mapk14  \
# patient_id
# 0          -0.2537 -1.0723  0.9728 -0.5303  1.1210 -0.7856 -0.4231  1.4091
# 2           1.4577  0.4849 -1.9242  1.3903  2.8106 -0.8652 -0.2488  0.7743
# 5           0.8589  1.7950  0.9890  1.5604  2.0526  0.8695 -1.8879 -2.2948
# 6          -0.6734  1.5143 -0.4072  1.6567  2.6831 -0.2603 -1.6951 -1.7671
# 8           0.5698 -0.9309  0.7014  0.3155  1.0845 -0.9843 -0.7672 -1.0214
#
#               bap1   bcas3   birc6  cacna2d3   ccnd3    chd1    clk3   clrn2  \
# patient_id
# 0          -0.9975 -0.6185 -1.0493    0.0055  0.2307  0.2223 -0.1376  0.2433
# 2           0.3675 -1.1052  1.3807   -0.4037 -0.9088  0.0454 -0.7820 -0.8355
# 5          -2.6732 -0.5876 -0.3068    1.8081 -2.6859  0.6366 -1.6504 -0.6838
# 6          -3.8521 -0.6948  1.9645   -0.0030 -0.6588  2.0459 -1.4345  0.3367
# 8           0.2162 -0.1630 -0.7862   -0.3866  1.1366 -0.2469 -0.0795  0.2905
#
#             col12a1  col22a1  col6a3    ctcf  ctnna1  ctnna3  dnah11   dnah2  \
# patient_id
# 0           -0.6096  -0.3107 -0.3426 -0.4098 -0.0482  0.2311 -0.0721 -1.0962
# 2            1.0075  -0.2229  0.2785  0.2358 -1.2060 -0.8015 -0.9145 -1.1824
# 5            0.8384  -0.2396  0.9698 -0.8201  0.7313 -0.0799 -1.4797 -0.7075
# 6            0.7001  -0.4587  0.6020 -0.6187  0.9967 -0.8569 -0.7878 -1.1014
# 8           -0.9057  -0.9781 -1.1143 -0.1674  0.5049  0.2764 -0.7933 -1.1111
#
#              dnah5   dtwd2  fam20c   fanca  fancd2    flt3   foxp1   frmd3  \
# patient_id
# 0          -0.9616 -1.2864  1.4018  0.7203 -2.0976 -0.5296 -0.3045  1.3213
# 2           1.9868 -1.3597 -0.4388 -0.8625 -0.7109  1.7385 -0.1447 -0.4348
# 5          -0.3000  0.8004 -0.4371 -0.0681 -0.6161  0.7884  2.0214 -1.0083
# 6          -0.6013 -0.1297 -0.0893  0.6354 -0.2885 -0.1103  1.5297 -0.2226
# 8          -1.1666 -0.1833 -1.7009 -0.5370 -0.5824 -1.1332  0.6269 -0.7415
#
#                gh1    gldc   gpr32    gps2   hdac9   herc2  hist1h2bc   kdm3a  \
# patient_id
# 0           1.0185 -0.2863  0.2566  0.7920  1.5660  0.0066    -1.1763 -0.6926
# 2           1.9129  3.9959 -0.0545 -1.7629 -0.1561 -1.7101     1.0178  1.3896
# 5          -0.2739 -0.7664 -1.0429 -0.7136 -0.0906 -2.9315     0.7477  2.6560
# 6           0.5911  1.6744 -0.5610 -0.1025  0.3307 -2.4937     0.0737  1.4758
# 8          -0.5916 -0.2990  2.7664 -0.7149  0.3153 -1.2114     2.5406  0.5260
#
#              kdm6a   klrg1   l1cam   lama2   lamb3  large1  ldlrap1    lifr  \
# ...
# 0                    0          0          0          0           0
# 2                    0          0          0          0           0
# 5                    0          0          0          0           0
# 6                    0          0          0          0           0
# 8                    0          0          0          0           0
#
#             ahnak_mut  dnah11_mut  cdh1_mut  dnah2_mut  kmt2d_mut  ush2a_mut  \
# patient_id
# 0                   0           0         0          0          0          0
# 2                   0           0         0          0          0          0
# 5                   0           0         0          0          0          0
# 6                   0           0         0          0          0          0
# 8                   0           0         0          0          0          0
#
#             ryr2_mut  dnah5_mut  herc2_mut  pde4dip_mut  akap9_mut  tg_mut  \
# patient_id
# 0                  0          0          0            0          0       0
# 2                  0          0          0            0          0       0
# 5                  0          0          0            0          0       0
# 6                  0          0          0            0          0       0
# 8                  0          0          0            0          0       1
#
#             birc6_mut  utrn_mut  tbx3_mut  col6a3_mut  arid1a_mut  lama2_mut  \
# patient_id
# 0                   0         0         0           0           0          0
# 2                   0         0         0           0           0          0
# 5                   0         0         0           0           0          0
# 6                   0         0         0           0           0          0
# 8                   0         0         0           0           0          0
#
#             notch1_mut  cbfb_mut  ncor2_mut  col12a1_mut  col22a1_mut  \
# patient_id
# 0                    0         0          0            0            0
# 2                    0         0          0            0            0
# 5                    0         0          0            0            0
# 6                    0         0          0            0            0
# 8                    0         0          0            0            0
#
#             pten_mut  akt1_mut  atr_mut  thada_mut  ncor1_mut  stab2_mut  \
# patient_id
# 0                  0         0        0          0          0          0
# 2                  0         0        0          0          0          0
# 5                  0         0        0          0          1          0
# 6                  0         0        0          0          0          0
# 8                  0         0        0          0          0          0
#
#             myh9_mut  runx1_mut  nf1_mut  map2k4_mut  ros1_mut  lamb3_mut  \
# patient_id
# 0                  0          0        0           0         0          0
# 2                  0          0        0           0         0          0
# 5                  0          0        0           0         0          0
# 6                  0          0        0           0         0          0
# 8                  0          0        0           0         0          0
#
#             arid1b_mut  erbb2_mut  sf3b1_mut  shank2_mut  ep300_mut  \
# patient_id
# 0                    0          0          0           0          0
# 2                    0          0          0           0          0
# 5                    0          0          0           0          0
# 6                    0          0          0           0          0
# 8                    0          0          0           0          0
#
#             ptprd_mut  usp9x_mut  setd2_mut  setd1a_mut  thsd7a_mut  afdn_mut  \
# patient_id
# 0                   0          0          0           0           0         0
# 2                   0          0          0           0           0         0
# 5                   0          0          0           0           0         0
# 6                   0          0          0           0           0         0
# 8                   0          0          0           0           0         0
#
#             erbb3_mut  rb1_mut  myo1a_mut  alk_mut  fanca_mut  adgra2_mut  \
# patient_id
# 0                   0        0          0        0          0           0
# 2                   0        0          0        0          0           0
# 5                   0        0          0        0          0           0
# 6                   0        0          0        0          0           0
# 8                   0        0          0        0          0           0
#
#             ubr5_mut  pik3r1_mut  myo3a_mut  asxl2_mut  apc_mut  ctcf_mut  \
# patient_id
# 0                  0           0          0          0        0         0
# 2                  0           0          0          0        0         0
# 5                  0           0          0          0        0         0
# 6                  0           0          0          0        0         0
# 8                  0           0          0          0        0         0
#
#             asxl1_mut  fancd2_mut  taf1_mut  kdm6a_mut  ctnna3_mut  brca1_mut  \
# patient_id
# 0                   0           0         0          0           0          0
# 2                   0           0         0          0           0          0
# 5                   0           0         0          0           0          0
# 6                   0           0         0          0           0          0
# 8                   0           0         0          0           0          0
#
#             ptprm_mut  foxo3_mut  usp28_mut  gldc_mut  brca2_mut  \
# patient_id
# 0                   0          0          0         0          0
# 2                   0          1          0         0          0
# 5                   0          0          0         0          0
# 6                   0          0          0         0          0
# 8                   0          0          0         0          0
#
#             cacna2d3_mut  arid2_mut  aff2_mut  lifr_mut  sbno1_mut  kdm3a_mut  \
# patient_id
# 0                      0          0         0         0          0          0
# 2                      0          0         0         0          0          0
# 5                      0          0         0         0          0          0
# 6                      0          0         0         0          0          0
# 8                      0          0         0         0          0          0
#
#             ncoa3_mut  bap1_mut  l1cam_mut  pbrm1_mut  chd1_mut  jak1_mut  \
# patient_id
# 0                   0         0          0          0         0         0
# 2                   0         0          0          0         0         0
# 5                   0         0          0          0         0         0
# 6                   0         0          0          0         0         0
# 8                   0         0          0          0         0         0
#
#             setdb1_mut  fam20c_mut  arid5b_mut  egfr_mut  map3k10_mut  \
# patient_id
# 0                    0           0           0         0            0
# 2                    0           0           0         0            0
# 5                    0           0           0         0            0
# 6                    0           0           0         0            0
# 8                    0           0           0         0            0
#
#             smarcc2_mut  erbb4_mut  npnt_mut  nek1_mut  agmo_mut  zfp36l1_mut  \
# patient_id
# 0                     0          0         0         0         0            0
# 2                     0          0         0         0         0            0
# 5                     0          0         0         0         0            0
# 6                     0          0         0         0         0            0
# 8                     0          0         0         0         0            0
#
#             smad4_mut  sik1_mut  casp8_mut  prkcq_mut  smarcc1_mut  palld_mut  \
# patient_id
# 0                   0         0          0          0            0          0
# 2                   0         0          0          0            0          0
# 5                   0         0          0          0            0          0
# 6                   0         0          0          0            0          0
# 8                   0         0          0          0            0          0
#
#             dcaf4l2_mut  bcas3_mut  cdkn1b_mut  gps2_mut  men1_mut  stk11_mut  \
# patient_id
# 0                     0          0           0         0         0          0
# 2                     0          0           0         0         0          0
# 5                     0          0           0         0         0          0
# 6                     0          0           0         0         0          0
# 8                     0          0           0         0         0          0
#
#             sik2_mut  ptpn22_mut  brip1_mut  flt3_mut  nrg3_mut  fbxw7_mut  \
# patient_id
# 0                  0           0          0         0         0          0
# 2                  0           0          0         0         0          0
# 5                  0           0          0         0         0          0
# 6                  0           0          0         0         0          0
# 8                  0           0          0         0         0          0
#
#             ttyh1_mut  taf4b_mut  or6a2_mut  map3k13_mut  hdac9_mut  \
# patient_id
# 0                   0          0          0            0          0
# 2                   0          0          0            0          0
# 5                   0          0          0            0          0
# 6                   0          0          0            0          0
# 8                   0          0          0            0          0
#
#             prkacg_mut  rpgr_mut  large1_mut  foxp1_mut  clk3_mut  prkcz_mut  \
# patient_id
# 0                    0         0           0          0         0          0
# 2                    0         0           0          0         0          0
# 5                    0         0           0          0         0          0
# 6                    0         0           0          0         0          0
# 8                    0         0           0          0         0          0
#
#             lipi_mut  ppp2r2a_mut  prkce_mut  gh1_mut  gpr32_mut  kras_mut  \
# patient_id
# 0                  0            0          0        0          0         0
# 2                  0            0          0        0          0         0
# 5                  0            0          0        0          0         0
# 6                  0            0          0        0          0         0
# 8                  0            0          0        0          0         0
#
#             nf2_mut  chek2_mut  ldlrap1_mut  clrn2_mut  acvrl1_mut  agtr2_mut  \
# patient_id
# 0                 0          0            0          0           0          0
# 2                 0          0            0          0           0          0
# 5                 0          0            0          0           0          0
# 6                 0          0            0          0           0          0
# 8                 0          0            0          0           0          0
#
#             cdkn2a_mut  ctnna1_mut  magea8_mut  prr16_mut  dtwd2_mut  \
# patient_id
# 0                    0           0           0          0          0
# 2                    0           0           0          0          0
# 5                    0           0           0          0          0
# 6                    0           0           0          0          0
# 8                    0           0           0          0          0
#
#             akt2_mut  braf_mut  foxo1_mut  nt5e_mut  ccnd3_mut  nr3c1_mut  \
# patient_id
# 0                  0         0          0         0          0          0
# 2                  0         0          0         0          0          0
# 5                  0         0          0         0          0          0
# 6                  0         0          0         0          0          0
# 8                  0         0          0         0          0          0
#
#             prkg1_mut  tbl1xr1_mut  frmd3_mut  smad2_mut  sgcd_mut  \
# patient_id
# 0                   0            0          0          0         0
# 2                   0            0          0          0         0
# 5                   0            0          0          0         0
# 6                   0            0          0          0         0
# 8                   0            0          0          0         0
#
#             spaca1_mut  rasgef1b_mut  hist1h2bc_mut  nr2f1_mut  klrg1_mut  \
# patient_id
# 0                    0             0              0          0          0
# 2                    0             0              0          0          0
# 5                    0             0              0          0          0
# 6                    0             0              0          0          0
# 8                    0             0              0          0          0
#
#             mbl2_mut  mtap_mut  ppp2cb_mut  smarcd1_mut  nras_mut  ndfip1_mut  \
# patient_id
# 0                  0         0           0            0         0           0
# 2                  0         0           0            0         0           0
# 5                  0         0           0            0         0           0
# 6                  0         0           0            0         0           0
# 8                  0         0           0            0         0           0
#
#             hras_mut  prps2_mut  smarcb1_mut  stmn2_mut  siah1_mut
# patient_id
# 0                  0          0            0          0          0
# 2                  0          0            0          0          0
# 5                  0          0            0          0          0
# 6                  0          0            0          0          0
# 8                  0          0            0          0          0

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1903 entries, 0 to 7299
# Columns: 754 entries, age_at_diagnosis to siah1_mut
# dtypes: float64(492), int64(262)
# memory usage: 11.0 MB

# %%
# checking data types
num_data.dtypes
# Out:
# age_at_diagnosis                 float64
# lymph_nodes_examined_positive      int64
# mutation_count                     int64
# nottingham_prognostic_index      float64
# overall_survival_months          float64
#                                   ...
# hras_mut                           int64
# prps2_mut                          int64
# smarcb1_mut                        int64
# stmn2_mut                          int64
# siah1_mut                          int64
# Length: 754, dtype: object

# %%
# confirming no missing data
num_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## 3.5 PCA <a id='3.5_pca'></a>

# %% [markdown]
# ### How many features do I need to keep to avoid wide & short?

# %%
# to figure out how much of my data to keep, I ideally want 10 times as many rows as features so that it's not wide and short.
rows = num_data.shape[0]
ideal_features = rows/10
print('Ideal number of features:',ideal_features)
# Out:
# Ideal number of features: 190.3

# %% [markdown]
# I will aim to have 190 features or less, if possible. I will keep this in mind during the next step.

# %% [markdown]
# ### Prepare data for PCA

# %%
# I need to drop the extra death_from_cancer_1 column, and rename death_from_cancer_0 to just outcome
#MAKING A CHANGE : 0 = Survived or died of other causes, 1 = Died of Disease

num_data = num_data.rename(columns={"death_from_cancer_0":"outcome"})
num_data = num_data.drop("death_from_cancer_1",axis=1)

# %%
#move outcomes to the first column
first_column= num_data.pop('outcome')
num_data.insert(0, 'outcome', first_column)

# %%
num_data.head()
# Out:
#             outcome  age_at_diagnosis  lymph_nodes_examined_positive  \
# patient_id
# 0                 0             75.65                             10
# 2                 0             43.19                              0
# 5                 1             48.87                              1
# 6                 0             47.68                              3
# 8                 1             76.97                              8
#
#             mutation_count  nottingham_prognostic_index  \
# patient_id
# 0                        0                        6.044
# 2                        2                        4.020
# 5                        2                        4.030
# 6                        1                        4.050
# 8                        2                        6.080
#
#             overall_survival_months  tumor_size  \
# patient_id
# 0                             140.5        22.0
# 2                              84.6        10.0
# 5                             163.7        15.0
# 6                             164.9        25.0
# 8                              41.4        40.0
#
#             type_of_breast_surgery_BREAST CONSERVING  \
# patient_id
# 0                                                  0
# 2                                                  1
# 5                                                  0
# 6                                                  0
# 8                                                  0
#
#             type_of_breast_surgery_MASTECTOMY  type_of_breast_surgery_nan  \
# patient_id
# 0                                           1                           0
# 2                                           0                           0
# 5                                           1                           0
# 6                                           1                           0
# 8                                           1                           0
#
#             cancer_type_Breast Cancer  cancer_type_Breast Sarcoma  \
# patient_id
# 0                                   1                           0
# 2                                   1                           0
# 5                                   1                           0
# 6                                   1                           0
# 8                                   1                           0
#
#             cancer_type_detailed_Breast  \
# patient_id
# 0                                     0
# 2                                     0
# 5                                     0
# 6                                     0
# 8                                     0
#
#             cancer_type_detailed_Breast Invasive Ductal Carcinoma  \
# patient_id
# 0                                                               1
# 2                                                               1
# 5                                                               1
# 6                                                               0
# 8                                                               0
#
#             cancer_type_detailed_Breast Invasive Lobular Carcinoma  \
# patient_id
# 0                                                                0
# 2                                                                0
# 5                                                                0
# 6                                                                0
# 8                                                                0
#
#             cancer_type_detailed_Breast Invasive Mixed Mucinous Carcinoma  \
# patient_id
# 0                                                                       0
# 2                                                                       0
# 5                                                                       0
# 6                                                                       0
# 8                                                                       0
#
#             cancer_type_detailed_Breast Mixed Ductal and Lobular Carcinoma  \
# patient_id
# 0                                                                        0
# 2                                                                        0
# 5                                                                        0
# 6                                                                        1
# 8                                                                        1
#
#             cancer_type_detailed_Metaplastic Breast Cancer  \
# patient_id
# 0                                                        0
# 2                                                        0
# 5                                                        0
# 6                                                        0
# 8                                                        0
#
#             cancer_type_detailed_nan  cellularity_High  cellularity_Low  \
# patient_id
# 0                                  0                 0                0
# 2                                  0                 1                0
# 5                                  0                 1                0
# 6                                  0                 0                0
# 8                                  0                 1                0
#
#             cellularity_Moderate  cellularity_nan  chemotherapy_0  \
# patient_id
# 0                              0                1               1
# 2                              0                0               1
# 5                              0                0               0
# 6                              1                0               0
# 8                              0                0               0
#
#             chemotherapy_1  pam50_+_claudin-low_subtype_Basal  \
# patient_id
# 0                        0                                  0
# 2                        0                                  0
# 5                        1                                  0
# 6                        1                                  0
# 8                        1                                  0
#
#             pam50_+_claudin-low_subtype_Her2  \
# patient_id
# 0                                          0
# 2                                          0
# 5                                          0
# 6                                          0
# 8                                          0
#
#             pam50_+_claudin-low_subtype_LumA  \
# patient_id
# 0                                          0
# 2                                          1
# 5                                          0
# 6                                          0
# 8                                          0
#
#             pam50_+_claudin-low_subtype_LumB  pam50_+_claudin-low_subtype_NC  \
# patient_id
# 0                                          0                               0
# 2                                          0                               0
# 5                                          1                               0
# 6                                          1                               0
# 8                                          1                               0
#
#             pam50_+_claudin-low_subtype_Normal  \
# patient_id
# 0                                            0
# 2                                            0
# 5                                            0
# 6                                            0
# 8                                            0
#
#             pam50_+_claudin-low_subtype_claudin-low  cohort_1  cohort_2  \
# patient_id
# 0                                                 1         1         0
# 2                                                 0         1         0
# 5                                                 0         1         0
# 6                                                 0         1         0
# 8                                                 0         1         0
#
#             cohort_3  cohort_4  cohort_5  er_status_measured_by_ihc_Negative  \
# patient_id
# 0                  0         0         0                                   0
# 2                  0         0         0                                   0
# 5                  0         0         0                                   0
# 6                  0         0         0                                   0
# 8                  0         0         0                                   0
#
#             er_status_measured_by_ihc_Positive  er_status_measured_by_ihc_nan  \
# patient_id
# 0                                            1                              0
# 2                                            1                              0
# 5                                            1                              0
# 6                                            1                              0
# 8                                            1                              0
#
#             er_status_Negative  er_status_Positive  \
# patient_id
# 0                            0                   1
# 2                            0                   1
# 5                            0                   1
# 6                            0                   1
# 8                            0                   1
#
#             neoplasm_histologic_grade_1.0  neoplasm_histologic_grade_2.0  \
# patient_id
# 0                                       0                              0
# 2                                       0                              0
# 5                                       0                              1
# 6                                       0                              1
# 8                                       0                              0
#
#             neoplasm_histologic_grade_3.0  neoplasm_histologic_grade_nan  \
# patient_id
# 0                                       1                              0
# 2                                       1                              0
# 5                                       0                              0
# 6                                       0                              0
# 8                                       1                              0
#
#             her2_status_measured_by_snp6_GAIN  \
# patient_id
# 0                                           0
# 2                                           0
# 5                                           0
# 6                                           0
# 8                                           0
#
#             her2_status_measured_by_snp6_LOSS  \
# patient_id
# 0                                           0
# 2                                           0
# 5                                           0
# 6                                           0
# 8                                           0
#
#             her2_status_measured_by_snp6_NEUTRAL  \
# patient_id
# 0                                              1
# 2                                              1
# 5                                              1
# 6                                              1
# 8                                              1
#
#             her2_status_measured_by_snp6_UNDEF  her2_status_Negative  \
# patient_id
# 0                                            0                     1
# 2                                            0                     1
# 5                                            0                     1
# 6                                            0                     1
# 8                                            0                     1
#
#             her2_status_Positive  tumor_other_histologic_subtype_Ductal/NST  \
# patient_id
# 0                              0                                          1
# 2                              0                                          1
# 5                              0                                          1
# 6                              0                                          0
# 8                              0                                          0
#
#             tumor_other_histologic_subtype_Lobular  \
# patient_id
# 0                                                0
# 2                                                0
# 5                                                0
# 6                                                0
# 8                                                0
#
#             tumor_other_histologic_subtype_Medullary  \
# patient_id
# 0                                                  0
# 2                                                  0
# 5                                                  0
# 6                                                  0
# 8                                                  0
#
#             tumor_other_histologic_subtype_Metaplastic  \
# patient_id
# 0                                                    0
# 2                                                    0
# 5                                                    0
# 6                                                    0
# 8                                                    0
#
#             tumor_other_histologic_subtype_Mixed  \
# patient_id
# 0                                              0
# 2                                              0
# 5                                              0
# 6                                              1
# 8                                              1
#
#             tumor_other_histologic_subtype_Mucinous  \
# patient_id
# 0                                                 0
# 2                                                 0
# 5                                                 0
# 6                                                 0
# 8                                                 0
#
#             tumor_other_histologic_subtype_Other  \
# patient_id
# 0                                              0
# 2                                              0
# 5                                              0
# 6                                              0
# 8                                              0
#
#             tumor_other_histologic_subtype_Tubular/ cribriform  \
# patient_id
# 0                                                            0
# 2                                                            0
# 5                                                            0
# 6                                                            0
# 8                                                            0
#
#             tumor_other_histologic_subtype_nan  hormone_therapy_0  \
# patient_id
# 0                                            0                  0
# 2                                            0                  0
# 5                                            0                  0
# 6                                            0                  0
# 8                                            0                  0
#
#             hormone_therapy_1  inferred_menopausal_state_Post  \
# patient_id
# 0                           1                               1
# 2                           1                               0
# 5                           1                               0
# 6                           1                               0
# 8                           1                               1
#
#             inferred_menopausal_state_Pre  primary_tumor_laterality_Left  \
# patient_id
# 0                                       0                              0
# 2                                       1                              0
# 5                                       1                              0
# 6                                       1                              0
# 8                                       0                              0
#
#             primary_tumor_laterality_Right  primary_tumor_laterality_nan  \
# patient_id
# 0                                        1                             0
# 2                                        1                             0
# 5                                        1                             0
# 6                                        1                             0
# 8                                        1                             0
#
#             oncotree_code_BREAST  oncotree_code_IDC  oncotree_code_ILC  \
# patient_id
# 0                              0                  1                  0
# 2                              0                  1                  0
# 5                              0                  1                  0
# 6                              0                  0                  0
# 8                              0                  0                  0
#
#             oncotree_code_IMMC  oncotree_code_MBC  oncotree_code_MDLC  \
# patient_id
# 0                            0                  0                   0
# 2                            0                  0                   0
# 5                            0                  0                   0
# 6                            0                  0                   1
# 8                            0                  0                   1
#
#             oncotree_code_nan  overall_survival_0  overall_survival_1  \
# patient_id
# 0                           0                   0                   1
# 2                           0                   0                   1
# 5                           0                   1                   0
# 6                           0                   0                   1
# 8                           0                   1                   0
#
#             pr_status_Negative  pr_status_Positive  radio_therapy_0  \
# patient_id
# 0                            1                   0                0
# 2                            0                   1                0
# 5                            0                   1                1
# 6                            0                   1                0
# 8                            0                   1                0
#
#             radio_therapy_1  3-gene_classifier_subtype_ER+/HER2- High Prolif  \
# patient_id
# 0                         1                                                0
# 2                         1                                                1
# 5                         0                                                0
# 6                         1                                                0
# 8                         1                                                1
#
#             3-gene_classifier_subtype_ER+/HER2- Low Prolif  \
# patient_id
# 0                                                        0
# 2                                                        0
# 5                                                        0
# 6                                                        0
# 8                                                        0
#
#             3-gene_classifier_subtype_ER-/HER2-  \
# patient_id
# 0                                             1
# 2                                             0
# 5                                             0
# 6                                             0
# 8                                             0
#
#             3-gene_classifier_subtype_HER2+  3-gene_classifier_subtype_nan  \
# patient_id
# 0                                         0                              0
# 2                                         0                              0
# 5                                         0                              1
# 6                                         0                              1
# 8                                         0                              0
#
#             tumor_stage_0.0  tumor_stage_1.0  tumor_stage_2.0  \
# patient_id
# 0                         0                0                1
# 2                         0                1                0
# 5                         0                0                1
# 6                         0                0                1
# 8                         0                0                1
#
#             tumor_stage_3.0  tumor_stage_4.0  tumor_stage_nan   brca2   palb2  \
# patient_id
# 0                         0                0                0 -0.5738 -1.6217
# 2                         0                0                0  0.2777 -1.2154
# 5                         0                0                0 -0.8426  0.2114
# 6                         0                0                0 -0.5428 -1.6592
# 8                         0                0                0 -0.9039 -0.7219
#
#               pten    tp53     atm    cdh1   chek2     nbn     nf1   stk11  \
# patient_id
# 0           1.4524  0.3504  1.1517  0.0348  0.1266 -0.8361 -0.8578 -0.4294
# 2           0.5296 -0.0136 -0.2659  1.3594  0.7961  0.5419 -2.6059  0.5120
# 5          -0.3326  0.5141 -0.0803  1.1398  0.4187 -0.4030 -1.1305  0.2362
# 6           0.6369  1.6708 -0.8880  1.2491 -1.1889 -0.4174 -0.6165  1.0078
# 8           0.2168  0.3484  0.3897  0.9131  0.9356  0.7675 -0.2940 -0.2961
#
#              bard1    mlh1    msh2    msh6    pms2   epcam  rad51c  rad51d  \
# patient_id
# 0          -1.1201 -0.4844 -0.7483 -1.6660 -0.1250 -0.3721 -0.6508 -0.1278
# 2           0.4390  1.2266  0.7612  0.1821  1.0104  0.5600 -0.4018 -0.2909
# 5          -0.1721 -1.7910  3.0955  0.6608  2.6127  2.5553 -0.0391 -0.4421
# 6          -0.4010 -1.3905  4.8798  0.0615  2.9414  4.1161 -0.3098 -1.3470
# 8           0.6320 -0.3582  0.3032  0.8747  0.6323  0.3349 -0.2652 -0.1541
#
#              rad50     rb1    rbl1    rbl2   ccna1   ccnb1    cdk1   ccne1  \
# patient_id
# 0           1.7330 -0.2770 -1.0673  0.0615  0.1034 -1.6635 -2.0649 -1.3388
# 2           0.7440 -1.7488  0.4602  0.7835 -0.2690 -0.2715  0.3895 -0.6273
# 5           1.4528  1.4142  0.3143 -0.0662 -0.5558  0.6967  1.2949 -0.1245
# 6           1.2102  1.5345 -0.6347  0.7279  0.0219  1.8801  0.0476 -0.6651
# 8          -0.7631  1.0158  1.8996  0.6618 -0.7454  0.2862  1.1035 -1.0514
#
#               cdk2  cdc25a   ccnd1    cdk4    cdk6   ccnd2  cdkn2a  cdkn2b  \
# patient_id
# 0          -0.6208 -1.7309 -0.8059 -1.1037  0.0744  1.4313 -0.5785  1.2180
# 2           0.1813 -1.2643  1.1057  0.4108 -0.6040  0.0546  0.2754 -0.0952
# 5          -0.1109 -0.3923 -1.2747 -0.5312  0.2585  0.8958 -0.2270  1.1899
# 6          -1.4457 -0.3827 -0.4537 -1.5248  0.3689  1.1455  0.0432  1.0868
# 8           1.5423  1.2169  0.1169  1.7648  0.8892 -1.0195  0.3664  0.7145
#
#                myc  cdkn1a  cdkn1b    e2f1    e2f2    e2f3    e2f4    e2f5  \
# patient_id
# 0           2.5602  2.3152 -0.2487  0.1601 -1.8799 -1.3629  0.1992 -0.0907
# 2           0.7248  0.4389  1.8759 -1.8984 -0.3327 -1.4560  1.0011  0.0519
# 5          -0.7207  1.4829  3.0696  2.2248 -1.4859 -0.4127 -0.8333  0.2885
# 6          -0.5237  0.2119  3.4617  0.4610 -1.5404 -0.2119 -0.8333  1.8323
# 8           0.5223  1.5638  0.1562 -0.2666  0.4509 -0.4449 -0.3181  2.2129
#
#               e2f6    e2f7    e2f8     src    jak1    jak2   stat1   stat2  \
# patient_id
# 0          -0.1167 -1.3917 -0.8178 -1.0737  1.1097  1.6186  0.0413 -0.7556
# 6           1.1498 -1.5455 -0.2630 -0.8255 -0.9941 -2.5452 -1.5746 -1.1520
# 8          -1.4281 -2.7196 -0.0878 -2.1710 -2.1310 -0.7509 -0.0075  0.6149
#
#             notch3   nrarp    numb   numbl   psen1   psen2  psenen    rbpj  \
# patient_id
# 0          -0.8725 -0.6873 -0.4592 -0.3334  0.4056 -1.0686 -0.3936  1.1433
# 2          -1.4752  1.0167 -0.4651  0.8040  0.6743 -0.6104  0.6839 -0.4825
# 5           0.3654 -0.6829  2.3143 -0.0641  1.3108 -1.0017  2.7082  0.0557
# 6          -0.5382 -0.8165  2.3152  1.2117  1.1638 -1.5603  0.7708  1.1797
# 8          -1.4361 -1.6582 -0.7700 -0.3525  2.1816 -0.4056  0.7125 -0.4021
#
#              rbpjl    rfng    snw1    spen    hes2    hes4    hes7    hey1  \
# patient_id
# 0          -0.0714  0.2433  0.0513  0.2550 -0.3139  0.0938 -1.3190 -0.2490
# 2           1.4183 -0.0538  2.1712  1.2776 -0.0013  1.2396 -2.1458  0.3879
# 5          -1.6488 -0.0451  3.8545 -2.5468 -0.7339 -0.1023  0.6490  1.4153
# 6          -0.6543  1.4984  4.1430 -2.8894  1.3690 -0.4797  0.3536 -0.2092
# 8           0.3117  0.0706 -0.5673 -0.6666 -0.5381  0.4906 -0.1500 -0.4913
#
#               hey2   acvr1  acvr1b  acvr1c  acvr2a  acvr2b  acvrl1    akt1  \
# patient_id
# 0           2.0761  0.4710 -0.9114  1.8079 -0.9273 -0.7363  2.9004 -1.1280
# 2          -0.4597  0.8386  0.6737  0.7279  1.0905  0.5358 -1.8416  0.0312
# 5           2.0196  2.2031 -1.7817  0.6777  1.5452 -0.5908 -1.2039  0.9269
# 6           0.4415  1.0455 -1.2848 -0.4277  2.9200  0.5155 -1.7602  1.2375
# 8          -0.8568 -0.7534  0.6626  0.2038  0.4134 -0.0238 -0.8343 -0.9541
#
#             akt1s1    akt2   apaf1   arl11     atr   aurka     bad    bcl2  \
# patient_id
# 0          -0.4574  0.2391 -1.8513 -0.0124 -0.6790 -1.5733 -0.3367  0.5371
# 2          -0.1056  0.6519 -0.0742 -0.5111  0.5127 -0.3052  1.8906  0.3243
# 5           0.1185  1.2371  0.1704  0.0771  0.0012 -0.2248  1.3090 -1.0989
# 6          -1.0408 -0.1938  0.2536 -0.5253 -0.5074  2.0447 -0.1371  0.2252
# 8          -0.8911  2.1021 -0.6142  0.0657 -0.3322  0.5882  0.5063 -1.2477
#
#             bcl2l1   bmp10   bmp15    bmp2    bmp3    bmp4    bmp5    bmp6  \
# patient_id
# 0          -0.1719  0.0308 -0.8320  4.7741  1.8812  0.7940  0.2512  2.5915
# 2          -0.5759  2.6618  3.3397 -1.1385 -0.3217  0.7861 -0.1874 -0.3346
# 5           0.3435  0.3679  1.5678 -0.7861  0.2980  2.0460  1.3173 -0.3617
# 6           0.7383  0.2514  0.7842 -0.6000  0.9754 -0.3231 -0.0546 -0.1192
# 8           1.2839 -0.6159 -0.1525 -0.5262  0.6704  0.1790 -0.0792  0.5098
#
#               bmp7  bmpr1a  bmpr1b   bmpr2    braf  casp10   casp3   casp6  \
# patient_id
# 0          -0.3928  1.1934 -0.8505  0.9883 -0.6387  0.3033 -2.1257 -0.8434
# 2           0.2365 -0.3413  0.5569  0.1759  0.5886  0.1039  0.5775  1.7652
# 5          -0.4294  0.4681  0.4623  1.7894  0.7275 -0.8205 -0.9291  1.7003
# 6           4.1957  1.0486 -0.4867  2.3596  0.2123  1.2658  0.5207  0.0513
# 8           2.4848  0.8654 -1.0298 -0.7718 -0.2628  0.1754 -0.5207 -0.5943
#
#              casp7   casp8   casp9   chek1    csf1   csf1r   cxcl8   cxcr1  \
# patient_id
# 0           0.6977  0.1816 -0.4332 -1.6332 -0.0424  0.4810  0.1226  0.9278
# 2          -0.1495  1.8819 -0.4484 -0.9604  0.2664 -2.1839 -1.1673 -1.2491
# 5           1.0673  0.6432 -1.2527  0.7585 -0.6927 -0.5916  1.2092  0.0089
# 6           1.5423 -1.1012  0.6762 -0.8414  0.2440 -0.7753  0.0309 -0.0706
# 8           0.9725  1.8931 -0.3756  0.4420 -0.0896 -0.3344 -0.3125 -0.9502
#
#              cxcr2    dab2  diras3   dlec1    dph1    egfr   eif4e  eif4ebp1  \
# patient_id
# 0          -0.0070  1.2766  0.2883 -0.4517  1.1179  2.0696 -0.2314   -0.2265
# 2           0.4389 -1.7476  0.6600  0.4479  1.6732 -0.3609  0.9246   -0.3173
# 5          -1.8753 -0.7936 -0.1572 -0.6188  0.2521 -0.0991  3.1838   -0.5358
# 6           1.8137  0.1723  0.2875 -0.7166  1.4561 -0.7250  2.9343   -0.2353
# 8           0.7129 -0.3024 -0.5542  0.0629  1.3411 -0.5042  0.4861    1.2588
#
#             eif5a2   erbb2   erbb3   erbb4     fas    fgf1   fgfr1   folr1  \
# patient_id
# 0           0.5513 -1.0548 -1.7207  0.2415 -0.1829  2.2525  1.7000  1.6797
# 2          -0.5307 -0.7633  0.5803  0.0059 -0.4012 -0.8545  0.3062 -0.7914
# 5           0.2586 -0.7661 -1.3607 -0.4383  2.1470  0.9773 -0.4567 -0.4299
# 6           0.4649 -0.3172 -0.6405 -0.5122  1.8836  0.4925 -0.7820 -0.5803
# 8          -1.0460 -0.5962  1.4865 -1.0922  0.5010 -1.0715  0.8701  0.5115
#
#              folr2   folr3   foxo1   foxo3   gdf11    gdf2   gsk3b   hif1a  \
# patient_id
# 0           1.0893  0.4606  2.5507  0.9213 -0.6499 -1.5386 -0.7982  0.4191
# 2          -0.9169 -0.0141 -0.7180 -1.6144  0.0169  1.9384 -0.0094 -0.8038
# 5           0.5313  0.3959 -0.4464 -1.2823 -1.2771  0.5162 -1.7768  3.5336
# 6           1.3413  0.6259  0.4124 -1.2511 -0.9396 -2.8998 -1.6895  3.3403
# 8           0.6556  0.3455 -1.1731 -1.5713 -0.3794  0.5430 -0.3001  1.3211
#
#              hla-g    hras    igf1   igf1r    inha   inhba   inhbc   itgav  \
# patient_id
# 0           0.1048 -0.9923  0.9947 -0.4445  0.0883  1.1190 -0.4613 -0.4337
# 2          -0.9355  0.9679  0.8191  0.0638 -0.2797 -0.6347 -0.2217 -0.7036
# 5           1.9768 -0.6058  1.5676 -0.6426 -0.4539 -0.3512 -1.4372  2.2121
# 6           2.0772  0.9831  2.8491 -0.7844  1.9837  0.6968  0.1198  1.3652
# 8           0.0246  0.2881 -0.2109 -0.5785 -0.1702 -0.5076  0.3660 -1.2198
#
#              itgb3  izumo1r     kdr     kit    kras  map2k1  map2k2  map2k3  \
# patient_id
# 0          -0.2304   0.7302  2.7183  2.9336 -2.1663  0.4229 -0.0078  2.6548
# 2           0.2577  -0.9707 -0.9864 -0.4866 -0.6278 -2.0640 -0.5408 -1.9500
# 5           0.6469  -1.1507 -0.4649  0.4321  0.5189  0.0169 -0.8582 -2.2248
# 6          -0.8502  -0.8229 -1.2923 -0.5447  0.5582 -0.2496 -1.4272 -0.0413
# 8          -0.3194   1.0331 -1.7323 -0.1758 -0.6360  0.4079 -2.2363 -0.1867
#
#             map2k4  map2k5  map3k1  map3k3  map3k4  map3k5   mapk1  mapk12  \
# patient_id
# 0          -0.0279 -0.2537 -1.0723  0.9728 -0.5303  1.1210 -0.7856 -0.4231
# 2          -1.1421 -1.0739  1.3129 -1.6056 -0.7564  0.4997 -0.4899 -0.3840
# 5           0.6299 -2.8788  1.6581 -2.2545 -0.6332  0.1242  0.3567 -0.4056
# 6           1.0026 -2.2113  1.0801 -1.3444 -0.1964 -0.3292 -0.3793  0.2475
# 8          -0.3795 -0.4151 -1.2170 -0.2842 -2.3884 -0.3605  1.2317  0.3536
#
#             mapk14   mapk3   mapk4   mapk6   mapk7   mapk8   mapk9    mdc1  \
# patient_id
# 0           1.4091  0.9809  0.5448 -0.4627  0.3205 -2.4995 -0.8403 -0.6932
# 2           1.7598 -0.6298  0.2111 -0.9976 -0.6786  2.3882  0.5150 -1.1688
# 5           1.0982 -0.8799 -0.6478  1.8587 -1.6654  0.1825  1.0738 -1.5809
# 6          -0.2556  1.3314  1.6936  0.2379 -1.2308 -0.1847  0.2743 -0.8201
# 8           3.9901  0.5779 -1.0071  0.9238 -1.9312 -0.4494 -0.1982  0.3260
#
#              mlst8    mmp1   mmp10   mmp11   mmp12   mmp13   mmp14   mmp15  \
# patient_id
# 0          -1.0871 -0.8340 -0.7603 -3.2039 -0.5300 -0.8768 -0.5866 -0.8050
# 2          -0.1174 -0.4467 -0.7450  0.5243 -0.4845 -0.7357  0.1100 -0.0552
# 5          -1.7957  2.2321 -0.2289  0.7216 -0.0249  1.9421  2.7550  0.0417
# 6          -1.2531  1.2883 -0.3216  0.1539 -0.2261  2.8566  0.6631  1.7173
# 8           0.9414 -0.1305 -0.6322  0.0268 -0.5826 -0.2464 -1.7046 -0.2091
#
#              mmp16   mmp17   mmp19    mmp2   mmp21  mmp23b   mmp24   mmp25  \
# patient_id
# 0           1.1284  0.0194  1.7351 -0.1627  0.4474  0.7726  0.2549 -0.2840
# 2           0.9059  0.7236 -0.0589 -0.0365  1.1748  0.6258  1.1908  2.8068
# 5          -0.5516  0.0935  0.2619  0.2149  0.0325  0.0978 -0.1158 -1.2076
# 6           0.9451  0.4783  0.6355 -0.0788 -1.1357  0.1764  0.2230  0.2569
# 8           0.0024 -0.0867  0.1040 -0.6777  0.2603  1.9485 -0.9704  0.6494
#
#              mmp26   mmp27   mmp28    mmp3    mmp7    mmp9    mtor   nfkb1  \
# patient_id
# 0           0.7557  0.6495  3.9945 -1.3277  1.1844 -2.3771 -0.5469 -0.8838
# 2           0.0684  0.3887  0.2456 -1.1408 -1.5162 -1.3469 -0.3186 -0.8477
# 5          -0.0915  0.4895  0.3810 -0.1280  1.3559 -0.1297 -1.7472 -1.2457
# 6          -0.3969 -0.2373  0.8236 -0.4842 -0.1366 -0.7623 -1.9265 -2.0421
# 8          -0.7281  0.6346 -0.3306 -0.5542  0.0062 -0.7551 -0.6149 -1.3880
#
#              nfkb2   opcml   pdgfa   pdgfb  pdgfra  pdgfrb   pdpk1    peg3  \
# patient_id
# 0          -0.3837 -1.5136  1.0340 -0.0349  1.6642  0.1510 -0.2005  0.3824
# 2          -0.8394  0.8983 -0.3446 -0.3739  0.5016 -0.7094  0.2841  1.7849
# 5          -0.8461  0.2619 -1.3937 -1.6093  1.8002  0.0673 -0.4960 -0.9138
# 6          -0.7812 -0.4338 -0.4175 -0.4251  2.1803 -0.2670 -0.7175 -0.5943
# 8          -0.3511 -0.3835 -1.2038 -1.0203 -0.3866 -1.6346  1.4198  0.6252
#
#             pik3ca  pik3r1  pik3r2  plagl1    ptk2   rab25   rad51    raf1  \
# patient_id
# 0          -0.7545  2.0932 -3.1626  2.5054 -1.5906 -1.6133 -0.7447 -0.4185
# 2          -0.6025 -0.3072  0.2887 -0.4624 -0.7651  0.4303 -0.4151 -0.1043
# 5           2.2172  1.7297 -0.9902 -0.6465 -1.0594  0.3867 -0.1498 -1.8437
# 6           3.5440 -0.6674 -1.3752 -0.8595  2.6289  0.2140  0.8658 -0.6233
# 8          -0.4320 -1.1464 -0.2831 -0.3823  3.0912 -0.6780  1.8685 -1.2441
#
#             rassf1    rheb  rictor    rps6  rps6ka1  rps6ka2  rps6kb1  \
# patient_id
# 0           1.4167  0.7390 -1.1872  0.8191  -1.7290   0.6942  -0.5645
# 2           1.5891  0.7496 -0.0622  1.4198  -0.9011   0.1972  -1.4849
# 5           1.2840  1.0751  1.5229  1.3971  -2.2621  -0.1481  -1.2594
# 6          -0.2534  0.7494  1.2288  1.6454  -2.5622  -0.7248   1.4816
# 8           1.1045 -0.8958 -0.4307 -1.3988  -0.5631  -2.0748  -0.6419
#
#             rps6kb2   rptor  slc19a1   smad1   smad2   smad3   smad4   smad5  \
# patient_id
# 0           -1.8694  0.0165  -0.0677 -0.0464  0.7905  0.6308  0.2348 -0.3647
# 2            2.3000 -1.3098  -1.1252  0.9060  1.1109 -0.5117  0.8578 -0.5399
# 5           -1.0724 -1.5115  -0.7975  0.6871 -1.0038 -1.7931  1.4349  3.4869
# 6           -1.5166  0.4326  -0.4880 -0.5883  0.4072 -0.2181  0.8580  7.3425
# 8            1.4917 -0.3344   2.3240  0.5721 -0.7546 -0.7921  0.1512 -0.7187
#
#              smad6   smad7   smad9  sptbn1    terc    tert   tgfb1   tgfb2  \
# patient_id
# 0           0.0523  1.2775 -0.7776  2.9551  0.1389  2.0141 -0.6235  0.1020
# 2          -0.2627  0.3427  0.1040 -1.1895  0.2867  1.0530  0.0613 -0.1426
# 5          -0.1044 -0.2511 -0.8081 -1.0472 -1.0066  1.0893  0.4069  2.5760
# 6          -1.3747 -0.6002 -1.8264 -0.9305 -0.0247  0.3395  0.9068 -0.4965
# 8           0.3484 -0.5915 -0.7889 -1.0334 -0.0315 -0.9543 -1.0100  0.5378
#
#              tgfb3  tgfbr1  tgfbr2  tgfbr3    tsc1    tsc2   vegfa   vegfb  \
# patient_id
# 0          -1.4828 -0.6998  2.2907  2.0023  0.0623 -0.7012 -1.1656  1.4530
# 2           0.4945 -1.6412 -0.6814 -1.5001  0.8054 -0.6919 -0.4946  1.6321
# 5           1.1768  0.8615  0.2776 -1.0694 -0.9652 -1.3444 -1.0330 -1.0909
# 6           1.0085  0.3283  1.0795 -0.8085 -0.6103 -0.9989 -1.1922 -0.9584
# 8          -0.9729 -0.2201 -0.2670 -0.3679 -0.7420  0.4206  0.6806  2.0137
#
#              wfdc2    wwox  zfyve9  arid1a  arid1b    cbfb   gata3   kmt2c  \
# patient_id
# 0          -0.0897 -0.4464  0.7291 -1.2999 -0.2649 -0.2706 -1.7113 -0.9045
# 2           0.9657 -0.8286 -0.3056  1.9157 -0.9599  0.3507  1.1638 -0.0208
# 5           0.8227 -0.3171  0.0015 -0.9847 -0.3794  1.1649 -0.1419 -0.5063
# 6          -0.5884 -0.4584 -1.5983 -1.5992 -0.8519  1.4578 -0.5560 -1.2840
# 8          -0.6005  0.1638  1.3898  0.5634 -0.4830 -0.3686  0.1444 -1.1026
#
#              kmt2d    myh9   ncor1  pde4dip   ptprd    ros1   runx1    tbx3  \
# patient_id
# 0           2.6008  0.2852  0.3529   1.3600 -0.7693 -1.0379 -1.9710 -0.1164
# 2           0.9370 -1.8283  0.1916  -1.7667  0.5273  0.4946  0.6746  1.5592
# 5           0.1020  0.4317 -1.7078  -1.6482  1.4359  0.2610 -1.0401 -1.0888
# 6           1.4290  0.7069 -1.2370  -2.0525  1.3493  1.5894 -0.8902 -1.6030
# 8           1.4702 -1.7583 -0.2024  -0.2026 -0.7522  0.3038 -2.0765 -0.8439
#
#              abcb1  abcb11   abcc1  abcc10    bbc3     bmf  cyp2c8  cyp3a4  \
# patient_id
# 0           1.6758 -0.4071 -1.0213 -0.1948 -0.2122 -2.3395  0.2242 -0.0572
# 2          -1.1793 -0.0931  0.4261 -0.9788 -0.3817 -0.3431  0.4754  0.9464
# 5          -0.4457 -1.1208 -0.5168 -1.5536 -0.0325 -0.2389  1.3501 -1.3978
# 6          -0.8191 -0.7736 -1.4145 -0.9771  2.5351 -1.0042 -0.4249  1.1476
# 8          -0.3463  0.7826 -0.8794  0.0819 -0.9266 -0.0444 -0.5863 -0.1807
#
#               fgf2     fn1    map2    map4    mapt   nr1i2  slco1b3   tubb1  \
# patient_id
# 0           2.4435 -1.1291 -0.2147 -0.3917 -0.1692  0.6645  -0.1634  0.7029
# 2          -1.1548  0.6923 -0.5615  0.9038  1.2644 -0.6135  -0.5180  0.8972
# 5           0.5059  0.3415 -0.8314 -0.6845 -0.0460  1.1309   0.6809  0.3157
# 6           0.0401 -0.0785 -0.3800 -1.0618 -0.7920  2.5443  -0.2881  8.4721
# 8          -0.0446  0.8398 -0.1281 -0.2336 -0.4751 -1.1240  -0.0012  1.0188
#
#             tubb4a  tubb4b  twist1  adgra2    afdn    aff2    agmo   agtr2  \
# patient_id
# 0          -0.0250 -0.4113  2.8096  2.8014 -0.0004  0.9673  0.3011 -0.8436
# 2          -0.1003  0.7791 -0.2273 -0.4462 -1.9854  0.5022 -0.9526 -1.8435
# 5           1.2084 -0.6572  0.1984 -1.0721 -0.9729  0.0515  0.1109  0.9874
# 6           0.3142 -0.4413  0.1932 -1.0215  0.4553 -0.2354  0.4003  1.4839
# 8          -0.6606 -1.4697  0.4128 -1.5326 -0.4795  1.0052  0.9739  0.8825
#
#              ahnak  ahnak2   akap9     alk     apc   arid2  arid5b   asxl1  \
# patient_id
# 0           1.8227  0.3066 -0.7988  0.4355  0.5815 -1.4317  2.2128  0.6381
# 2           1.6662  1.4577  0.4849 -1.9242  1.3903  2.8106 -0.8652 -0.2488
# 5          -0.0154  0.8589  1.7950  0.9890  1.5604  2.0526  0.8695 -1.8879
# 6           0.3101 -0.6734  1.5143 -0.4072  1.6567  2.6831 -0.2603 -1.6951
# 8          -0.7598  0.5698 -0.9309  0.7014  0.3155  1.0845 -0.9843 -0.7672
#
#              asxl2    bap1   bcas3   birc6  cacna2d3   ccnd3    chd1    clk3  \
# patient_id
# 0          -1.4209 -0.9975 -0.6185 -1.0493    0.0055  0.2307  0.2223 -0.1376
# 2           0.7743  0.3675 -1.1052  1.3807   -0.4037 -0.9088  0.0454 -0.7820
# 5          -2.2948 -2.6732 -0.5876 -0.3068    1.8081 -2.6859  0.6366 -1.6504
# 6          -1.7671 -3.8521 -0.6948  1.9645   -0.0030 -0.6588  2.0459 -1.4345
# 8          -1.0214  0.2162 -0.1630 -0.7862   -0.3866  1.1366 -0.2469 -0.0795
#
#              clrn2  col12a1  col22a1  col6a3    ctcf  ctnna1  ctnna3  dnah11  \
# patient_id
# 0           0.2433  -0.6096  -0.3107 -0.3426 -0.4098 -0.0482  0.2311 -0.0721
# 2          -0.8355   1.0075  -0.2229  0.2785  0.2358 -1.2060 -0.8015 -0.9145
# 5          -0.6838   0.8384  -0.2396  0.9698 -0.8201  0.7313 -0.0799 -1.4797
# 6           0.3367   0.7001  -0.4587  0.6020 -0.6187  0.9967 -0.8569 -0.7878
# 8           0.2905  -0.9057  -0.9781 -1.1143 -0.1674  0.5049  0.2764 -0.7933
#
#              dnah2   dnah5   dtwd2  fam20c   fanca  fancd2    flt3   foxp1  \
# patient_id
# 0          -1.0962 -0.9616 -1.2864  1.4018  0.7203 -2.0976 -0.5296 -0.3045
# 2          -1.1824  1.9868 -1.3597 -0.4388 -0.8625 -0.7109  1.7385 -0.1447
# 5          -0.7075 -0.3000  0.8004 -0.4371 -0.0681 -0.6161  0.7884  2.0214
# 6          -1.1014 -0.6013 -0.1297 -0.0893  0.6354 -0.2885 -0.1103  1.5297
# 8          -1.1111 -1.1666 -0.1833 -1.7009 -0.5370 -0.5824 -1.1332  0.6269
#
#              frmd3     gh1    gldc   gpr32    gps2   hdac9   herc2  hist1h2bc  \
# patient_id
# 0           1.3213  1.0185 -0.2863  0.2566  0.7920  1.5660  0.0066    -1.1763
# 2          -0.4348  1.9129  3.9959 -0.0545 -1.7629 -0.1561 -1.7101     1.0178
# 5          -1.0083 -0.2739 -0.7664 -1.0429 -0.7136 -0.0906 -2.9315     0.7477
# 6          -0.2226  0.5911  1.6744 -0.5610 -0.1025  0.3307 -2.4937     0.0737
# 8          -0.7415 -0.5916 -0.2990  2.7664 -0.7149  0.3153 -1.2114     2.5406
#
#              kdm3a   kdm6a   klrg1   l1cam   lama2   lamb3  large1  ldlrap1  \
# patient_id
# 0          -0.6926  0.3471  1.1316  0.2378  2.6466  1.8590 -0.4848  -0.7400
# 2           1.3896 -0.2019 -1.1526 -0.4051  0.3336 -1.2531  0.7805  -0.3074
# ...
# 0                    0          0          0          0           0
# 2                    0          0          0          0           0
# 5                    0          0          0          0           0
# 6                    0          0          0          0           0
# 8                    0          0          0          0           0
#
#             ahnak_mut  dnah11_mut  cdh1_mut  dnah2_mut  kmt2d_mut  ush2a_mut  \
# patient_id
# 0                   0           0         0          0          0          0
# 2                   0           0         0          0          0          0
# 5                   0           0         0          0          0          0
# 6                   0           0         0          0          0          0
# 8                   0           0         0          0          0          0
#
#             ryr2_mut  dnah5_mut  herc2_mut  pde4dip_mut  akap9_mut  tg_mut  \
# patient_id
# 0                  0          0          0            0          0       0
# 2                  0          0          0            0          0       0
# 5                  0          0          0            0          0       0
# 6                  0          0          0            0          0       0
# 8                  0          0          0            0          0       1
#
#             birc6_mut  utrn_mut  tbx3_mut  col6a3_mut  arid1a_mut  lama2_mut  \
# patient_id
# 0                   0         0         0           0           0          0
# 2                   0         0         0           0           0          0
# 5                   0         0         0           0           0          0
# 6                   0         0         0           0           0          0
# 8                   0         0         0           0           0          0
#
#             notch1_mut  cbfb_mut  ncor2_mut  col12a1_mut  col22a1_mut  \
# patient_id
# 0                    0         0          0            0            0
# 2                    0         0          0            0            0
# 5                    0         0          0            0            0
# 6                    0         0          0            0            0
# 8                    0         0          0            0            0
#
#             pten_mut  akt1_mut  atr_mut  thada_mut  ncor1_mut  stab2_mut  \
# patient_id
# 0                  0         0        0          0          0          0
# 2                  0         0        0          0          0          0
# 5                  0         0        0          0          1          0
# 6                  0         0        0          0          0          0
# 8                  0         0        0          0          0          0
#
#             myh9_mut  runx1_mut  nf1_mut  map2k4_mut  ros1_mut  lamb3_mut  \
# patient_id
# 0                  0          0        0           0         0          0
# 2                  0          0        0           0         0          0
# 5                  0          0        0           0         0          0
# 6                  0          0        0           0         0          0
# 8                  0          0        0           0         0          0
#
#             arid1b_mut  erbb2_mut  sf3b1_mut  shank2_mut  ep300_mut  \
# patient_id
# 0                    0          0          0           0          0
# 2                    0          0          0           0          0
# 5                    0          0          0           0          0
# 6                    0          0          0           0          0
# 8                    0          0          0           0          0
#
#             ptprd_mut  usp9x_mut  setd2_mut  setd1a_mut  thsd7a_mut  afdn_mut  \
# patient_id
# 0                   0          0          0           0           0         0
# 2                   0          0          0           0           0         0
# 5                   0          0          0           0           0         0
# 6                   0          0          0           0           0         0
# 8                   0          0          0           0           0         0
#
#             erbb3_mut  rb1_mut  myo1a_mut  alk_mut  fanca_mut  adgra2_mut  \
# patient_id
# 0                   0        0          0        0          0           0
# 2                   0        0          0        0          0           0
# 5                   0        0          0        0          0           0
# 6                   0        0          0        0          0           0
# 8                   0        0          0        0          0           0
#
#             ubr5_mut  pik3r1_mut  myo3a_mut  asxl2_mut  apc_mut  ctcf_mut  \
# patient_id
# 0                  0           0          0          0        0         0
# 2                  0           0          0          0        0         0
# 5                  0           0          0          0        0         0
# 6                  0           0          0          0        0         0
# 8                  0           0          0          0        0         0
#
#             asxl1_mut  fancd2_mut  taf1_mut  kdm6a_mut  ctnna3_mut  brca1_mut  \
# patient_id
# 0                   0           0         0          0           0          0
# 2                   0           0         0          0           0          0
# 5                   0           0         0          0           0          0
# 6                   0           0         0          0           0          0
# 8                   0           0         0          0           0          0
#
#             ptprm_mut  foxo3_mut  usp28_mut  gldc_mut  brca2_mut  \
# patient_id
# 0                   0          0          0         0          0
# 2                   0          1          0         0          0
# 5                   0          0          0         0          0
# 6                   0          0          0         0          0
# 8                   0          0          0         0          0
#
#             cacna2d3_mut  arid2_mut  aff2_mut  lifr_mut  sbno1_mut  kdm3a_mut  \
# patient_id
# 0                      0          0         0         0          0          0
# 2                      0          0         0         0          0          0
# 5                      0          0         0         0          0          0
# 6                      0          0         0         0          0          0
# 8                      0          0         0         0          0          0
#
#             ncoa3_mut  bap1_mut  l1cam_mut  pbrm1_mut  chd1_mut  jak1_mut  \
# patient_id
# 0                   0         0          0          0         0         0
# 2                   0         0          0          0         0         0
# 5                   0         0          0          0         0         0
# 6                   0         0          0          0         0         0
# 8                   0         0          0          0         0         0
#
#             setdb1_mut  fam20c_mut  arid5b_mut  egfr_mut  map3k10_mut  \
# patient_id
# 0                    0           0           0         0            0
# 2                    0           0           0         0            0
# 5                    0           0           0         0            0
# 6                    0           0           0         0            0
# 8                    0           0           0         0            0
#
#             smarcc2_mut  erbb4_mut  npnt_mut  nek1_mut  agmo_mut  zfp36l1_mut  \
# patient_id
# 0                     0          0         0         0         0            0
# 2                     0          0         0         0         0            0
# 5                     0          0         0         0         0            0
# 6                     0          0         0         0         0            0
# 8                     0          0         0         0         0            0
#
#             smad4_mut  sik1_mut  casp8_mut  prkcq_mut  smarcc1_mut  palld_mut  \
# patient_id
# 0                   0         0          0          0            0          0
# 2                   0         0          0          0            0          0
# 5                   0         0          0          0            0          0
# 6                   0         0          0          0            0          0
# 8                   0         0          0          0            0          0
#
#             dcaf4l2_mut  bcas3_mut  cdkn1b_mut  gps2_mut  men1_mut  stk11_mut  \
# patient_id
# 0                     0          0           0         0         0          0
# 2                     0          0           0         0         0          0
# 5                     0          0           0         0         0          0
# 6                     0          0           0         0         0          0
# 8                     0          0           0         0         0          0
#
#             sik2_mut  ptpn22_mut  brip1_mut  flt3_mut  nrg3_mut  fbxw7_mut  \
# patient_id
# 0                  0           0          0         0         0          0
# 2                  0           0          0         0         0          0
# 5                  0           0          0         0         0          0
# 6                  0           0          0         0         0          0
# 8                  0           0          0         0         0          0
#
#             ttyh1_mut  taf4b_mut  or6a2_mut  map3k13_mut  hdac9_mut  \
# patient_id
# 0                   0          0          0            0          0
# 2                   0          0          0            0          0
# 5                   0          0          0            0          0
# 6                   0          0          0            0          0
# 8                   0          0          0            0          0
#
#             prkacg_mut  rpgr_mut  large1_mut  foxp1_mut  clk3_mut  prkcz_mut  \
# patient_id
# 0                    0         0           0          0         0          0
# 2                    0         0           0          0         0          0
# 5                    0         0           0          0         0          0
# 6                    0         0           0          0         0          0
# 8                    0         0           0          0         0          0
#
#             lipi_mut  ppp2r2a_mut  prkce_mut  gh1_mut  gpr32_mut  kras_mut  \
# patient_id
# 0                  0            0          0        0          0         0
# 2                  0            0          0        0          0         0
# 5                  0            0          0        0          0         0
# 6                  0            0          0        0          0         0
# 8                  0            0          0        0          0         0
#
#             nf2_mut  chek2_mut  ldlrap1_mut  clrn2_mut  acvrl1_mut  agtr2_mut  \
# patient_id
# 0                 0          0            0          0           0          0
# 2                 0          0            0          0           0          0
# 5                 0          0            0          0           0          0
# 6                 0          0            0          0           0          0
# 8                 0          0            0          0           0          0
#
#             cdkn2a_mut  ctnna1_mut  magea8_mut  prr16_mut  dtwd2_mut  \
# patient_id
# 0                    0           0           0          0          0
# 2                    0           0           0          0          0
# 5                    0           0           0          0          0
# 6                    0           0           0          0          0
# 8                    0           0           0          0          0
#
#             akt2_mut  braf_mut  foxo1_mut  nt5e_mut  ccnd3_mut  nr3c1_mut  \
# patient_id
# 0                  0         0          0         0          0          0
# 2                  0         0          0         0          0          0
# 5                  0         0          0         0          0          0
# 6                  0         0          0         0          0          0
# 8                  0         0          0         0          0          0
#
#             prkg1_mut  tbl1xr1_mut  frmd3_mut  smad2_mut  sgcd_mut  \
# patient_id
# 0                   0            0          0          0         0
# 2                   0            0          0          0         0
# 5                   0            0          0          0         0
# 6                   0            0          0          0         0
# 8                   0            0          0          0         0
#
#             spaca1_mut  rasgef1b_mut  hist1h2bc_mut  nr2f1_mut  klrg1_mut  \
# patient_id
# 0                    0             0              0          0          0
# 2                    0             0              0          0          0
# 5                    0             0              0          0          0
# 6                    0             0              0          0          0
# 8                    0             0              0          0          0
#
#             mbl2_mut  mtap_mut  ppp2cb_mut  smarcd1_mut  nras_mut  ndfip1_mut  \
# patient_id
# 0                  0         0           0            0         0           0
# 2                  0         0           0            0         0           0
# 5                  0         0           0            0         0           0
# 6                  0         0           0            0         0           0
# 8                  0         0           0            0         0           0
#
#             hras_mut  prps2_mut  smarcb1_mut  stmn2_mut  siah1_mut
# patient_id
# 0                  0          0            0          0          0
# 2                  0          0            0          0          0
# 5                  0          0            0          0          0
# 6                  0          0            0          0          0
# 8                  0          0            0          0          0

# %% [markdown]
# ### Train/test split and scaling

# %%
# first separate out my 'outcome' column
X = num_data.drop('outcome', axis=1)
y = num_data['outcome']

# %%
# perform train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# %%
#scale the data - don't do fit on test data so that we don't influence it with training data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
#verify the scaling:

# call the mean 
print('train data mean: ',np.mean(X_train))

# call the standard deviation:
print('train data standard deviation: ',np.std(X_train))
# Out:
# train data mean:  -8.210508882107645e-19
# train data standard deviation:  0.9986693274212014

# %% [markdown]
# ### Apply PCA

# %% [markdown]
# First, let's do it for 190 components, which means that we are following the rule of thumb of 10x as many rows as features.

# %%
# fit the training data
pca190 = PCA(n_components=190)
train_data_pca190 = pca190.fit(X_train)

# %% [markdown]
# Now let's do another PCA where we want it to account for 90% of the variance.

# %%
pca360 = PCA(n_components=0.90)
train_data_pca360 = pca360.fit(X_train)

# %%
print("Number of components when n_components set to 0.90: ", pca360.n_components_)
# Out:
# Number of components when n_components set to 0.90:  354

# %% [markdown]
# NOTE: Every time I run this, I get a slightly different number of components here. It was originally 360, so I'm using that as the variable name for consistency.

# %%
# plot the cumulative variance ratio explained by pca components. 

plt.subplots(figsize=(10, 6))
plt.plot(train_data_pca190.explained_variance_ratio_.cumsum(), linestyle='--', color='b')
plt.plot(train_data_pca360.explained_variance_ratio_.cumsum(), linestyle='--', color='b')
plt.xlabel('Component #')
plt.xticks(np.arange(0, 700, step=50))
plt.ylabel('Cumulative ratio variance')
plt.title('Cumulative variance ratio explained by PCA components')

plt.axhline(y=0.90, color='r', linestyle='-')
plt.axvline(x=np.argmax(train_data_pca360.explained_variance_ratio_.cumsum() >= 0.90), color='g', linestyle='--')
plt.text(np.argmax(train_data_pca360.explained_variance_ratio_.cumsum() >= 0.9) + 5, 0.85, '90% threshold', color='green')

# Add threshold line for 190 components
plt.axvline(x=190, color='m', linestyle='--')
plt.text(190 + 5, 0.7, '190 components', color='m')

plt.axhline(y=0.73, color='r', linestyle='-')

#plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)
plt.grid(axis='x')
plt.show;

# %%
plt.subplots(figsize=(10, 6))
plt.plot(train_data_pca190.explained_variance_ratio_)
plt.plot(train_data_pca360.explained_variance_ratio_)
plt.xlabel('Component #')
plt.grid(axis='x')
plt.xticks(np.arange(0, 474, step=25))
plt.xlim(right=474)
# Add threshold line for 190 components (73% variance)
plt.axvline(x=190, color='m', linestyle='--')
plt.text(190+5, 0.01, '190 components (73% var)', color='m')
# Add threshold line for 360 components (90% variance)
plt.axvline(x=360, color='b', linestyle='--')
plt.text(360+5, 0.01, '360 components (90% var)', color='m')


plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio for each PCA component')
plt.show()

# %% [markdown]
# <b>Summary so far</b>: 360 components has an explained variance ratio of 90%, and 190 components (which makes my data set good proportions) has an expalined variance ratio of 73% As you can see above, Each component accounts for a very small amount of variance in the data.

# %% [markdown]
# ### Transform the data

# %%
# 190 components
train_pca190_trans = pca190.transform(X_train)
test_pca190_trans = pca190.transform(X_test)

# 360 components
train_pca360_trans = pca360.transform(X_train)
test_pca360_trans = pca360.transform(X_test)

# %% [markdown]
# Let's look at a plot of the first 2 components:

# %%
# Create a dictionary to map outcome values to colors
color_dict = {1: 'red', 0: 'blue'}

# Create a list of colors for each data point based on the outcome column from the training set
colors = [color_dict[val] for val in y_train]

# Get the coordinates of the first two principal components
x = train_pca190_trans[:, 0]
y = train_pca190_trans[:, 1]

# Calculate the cumulative explained variance
pc_var = 100 * pca190.explained_variance_ratio_.cumsum()[1]

plt.subplots(figsize=(10,8))
plt.scatter(x=x, y=y, c=colors)
plt.xlabel('First component')
plt.ylabel('Second component')
plt.title(f'First Two Components of PCA, {pc_var:.1f}% variance explained')

# Add legend
handles = [plt.scatter([], [], c=color_dict[val], label=str(val)) for val in color_dict.keys()]
plt.legend(handles=handles, title='Outcome')

plt.show();

# %% [markdown]
# ## 3.6 Initial model: Logistic Regression  <a id='3.6_initial_model'></a>

# %% [markdown]
# ### 3.6.1 Logistic Regression  <a id='3.6.1_lr'></a>
# (a) train/test split (b) create an object of the class associated with the algorithm to be used--in this case LogisticRegression (c) build an actual model using the "fit" method from the class (applied to the training set) (d) predict with the built model using the "predict" method from the class (training set and test set) (e) compute performance metrics (in this case, accuracy) for the training and test predictions

# %%
# first rename things so that it's easier: 
X_train_190 = train_pca190_trans
X_train_360 = train_pca360_trans
X_train_full = X_train

X_test_190 = test_pca190_trans
X_test_360 = test_pca360_trans
X_test_full = X_test

# %%
# look at our split data: 

print('190 Training split (PCA n_components = 190) has ', X_train_190.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_train))+ ')\n')

print('360 Training split  PCA n_components = 360) has ', X_train_360.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_train))+ ')\n')


print('Full Training split( NO PCA)) has ', X_train.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_train)) + ')\n')



print('190 Test split (PCA n_components = 190) has ', X_test_190.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_test)) + ')\n')


print('360 Test split (PCA n_components = 360) has ', X_test_360.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_test)) + ')\n')


print('Full Test split (NO PCA) has ', X_test.shape[0], ' rows\n',
      'and the corresponding labels have an equal number of values.', 
      '(' + str(len(y_test)) + ')')
# Out:
# 190 Training split (PCA n_components = 190) has  1427  rows
#  and the corresponding labels have an equal number of values. (1427)
#
# 360 Training split  PCA n_components = 360) has  1427  rows
#  and the corresponding labels have an equal number of values. (1427)
#
# Full Training split( NO PCA)) has  1427  rows
#  and the corresponding labels have an equal number of values. (1427)
#
# 190 Test split (PCA n_components = 190) has  476  rows
#  and the corresponding labels have an equal number of values. (476)
#
# 360 Test split (PCA n_components = 360) has  476  rows
#  and the corresponding labels have an equal number of values. (476)
#
# Full Test split (NO PCA) has  476  rows
#  and the corresponding labels have an equal number of values. (476)

# %%
#define function to plot class ratios between the two splits of data

def plot_y_ratios(y_train, y_test):
    fig, ax = plt.subplots(2, sharex=True)
    
    # Calculate class counts and ratios for the train set
    train_counts = y_train.value_counts()
    train_ratios = train_counts / len(y_train)
    
    # Plot the train set class ratios
    ax[0].bar(x=[0, 1], height=[train_ratios[0], train_ratios[1]])
    ax[0].set_ylabel('train', fontsize=8)
    ax[0].set_ylim(0, 1)
    
    # Calculate class counts and ratios for the test set
    test_counts = y_test.value_counts()
    test_ratios = test_counts / len(y_test)
    
    # Plot the test set class ratios
    ax[1].bar(x=[0, 1], height=[test_ratios[0], test_ratios[1]])
    ax[1].set_ylabel('test', fontsize=8)
    ax[1].set_ylim(0, 1)
    ax[1].set_xticks([0, 1])
    
    # Set the x-axis label and plot title
    ax[1].set_xlabel('Outcome\n(0 = Did not die of disease)', fontsize=8)
    ax[0].set_title('% Death from Breast Cancer (where 1 means died of disease):\n' +
                    f'train: {train_ratios[1]*100:.1f}%\ntest: {test_ratios[1]*100:.1f}%',
                    fontsize=10)
    
    plt.show()

# %%
# compare class ratios for training and test sets. 
plot_y_ratios(y_train,y_test)

# %% [markdown]
# This is really close! I'm happy with this.

# %%
# Construct a LogisticRegrssion object

clf190 = LogisticRegression(solver = 'newton-cg', max_iter = 500)
clf360 = LogisticRegression(solver = 'newton-cg', max_iter = 500)
clf_full = LogisticRegression(solver = 'newton-cg', max_iter = 500)

# %%
# build a model for PCA190

clf190.fit(X_train_190,y_train)
# Out:
# LogisticRegression(max_iter=500, solver='newton-cg')

# %%
# build a model for PCA360
clf360.fit(X_train_360,y_train)
# Out:
# LogisticRegression(max_iter=500, solver='newton-cg')

# %%
# build a model for clf_full
clf_full.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=500, solver='newton-cg')

# %%
# predict for n_components = 190

y_predict_test_190 = clf190.predict(X_test_190)
y_predict_training_190 = clf190.predict(X_train_190)


# predict for n_components = 360

y_predict_test_360 = clf360.predict(X_test_360)
y_predict_training_360 = clf360.predict(X_train_360)

# predict for full set with all features

y_predict_test_full = clf_full.predict(X_test_full)
y_predict_training_full = clf_full.predict(X_train_full)

# %% [markdown]
# ### 3.6.2 Performance Metrics  <a id='3.6.2_metrics'></a>

# %% [markdown]
# Compute performance metrics and test predictions. First I'll look at accuracy, then confusion matrix, then classification report.

# %%
# Test set accuracy scores

print("[Test] Accuracy score (y_predict_test_190, y_test):",
      f'{accuracy_score(y_test,y_predict_test_190):.2f}')

print("[Test] Accuracy score (y_predict_test_360, y_test):",
      f'{accuracy_score(y_test,y_predict_test_360):.2f}')


print("[Test] Accuracy score (y_predict_test_full, y_test):",
      f'{accuracy_score(y_test,y_predict_test_full):.2f}')
# Out:
# [Test] Accuracy score (y_predict_test_190, y_test): 0.79
# [Test] Accuracy score (y_predict_test_360, y_test): 0.75
# [Test] Accuracy score (y_predict_test_full, y_test): 0.76

# %%
# Training set accuracy scores

print("[Training] Accuracy score for 190 components: (y_train, y_predict_training_190)", 
      f'{accuracy_score(y_train, y_predict_training_190):.2f}')

print("[Training] Accuracy score for 360 components: (y_train, y_predict_training_360)", 
      f'{accuracy_score(y_train, y_predict_training_360):.2f}')


print("[Training] Accuracy score for full features : (y_train, y_predict_training_full)", 
      f'{accuracy_score(y_train, y_predict_training_full):.2f}')
# Out:
# [Training] Accuracy score for 190 components: (y_train, y_predict_training_190) 0.88
# [Training] Accuracy score for 360 components: (y_train, y_predict_training_360) 0.97
# [Training] Accuracy score for full features : (y_train, y_predict_training_full) 1.00

# %% [markdown]
# There is clearly overfitting going on. It appears to be overfitting more with 190 components. Note that we shouldn't really trust the accuracy score by itself, especially because we have imbalanced classes.
#
# To summarize:</br>
# <b>Accuracy Scores for 190 components</b>:
#
# Test: 0.78 </br>
# Train: 0.97 </br>
#
# <b> Accuracy Scores for ~360 components </b>
#
# Test: 0.75 </br>
# Train: 0.88
#
# <b> Accuracy Scores for data with no PCA </b>
#
# Test: 0.76   </br>
# Train: 1.00

# %% [markdown]
# ### Confusion Matrix

# %%
# 190 components:

cm = confusion_matrix(y_test, y_predict_test_190, labels = clf190.classes_)
_, ax = plt.subplots()
display_cm = ConfusionMatrixDisplay(confusion_matrix = cm, 
                                    display_labels = ['no cancer death', 'cancer death'])
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
ax.set_yticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
plt.title('190 Components')
display_cm.plot(ax = ax)
plt.show();

# 360 components:

cm = confusion_matrix(y_test, y_predict_test_360, labels = clf360.classes_)
_, ax = plt.subplots()
display_cm = ConfusionMatrixDisplay(confusion_matrix = cm, 
                                    display_labels = ['no cancer death', 'cancer death'])
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
ax.set_yticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
plt.title('360 Components')
display_cm.plot(ax = ax)
plt.show();

# full data set (no PCA)
cm = confusion_matrix(y_test, y_predict_test_full, labels = clf_full.classes_)
_, ax = plt.subplots()
display_cm = ConfusionMatrixDisplay(confusion_matrix = cm, 
                                    display_labels = ['no cancer death', 'cancer death'])
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
ax.set_yticklabels(labels = ['no cancer death', 'cancer death'], fontsize = 8)
plt.title('No PCA')
display_cm.plot(ax = ax)
plt.show();

# %% [markdown]
# From these confusion matrixes it looks like the set with no PCA is the best at correctly labeling cancer death, followed by 360 components and 190 components. 190 components was the best at identifying 'no cancer death'. However, they were all quite close.

# %% [markdown]
# <b>Classification report for 190 components:</b>

# %%
# Training:

print(classification_report(y_train, y_predict_training_190))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       961
#            1       0.82      0.80      0.81       466
#
#     accuracy                           0.88      1427
#    macro avg       0.87      0.86      0.86      1427
# weighted avg       0.88      0.88      0.88      1427

# %%
# Testing:

print(classification_report(y_test, y_predict_test_190))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       320
#            1       0.70      0.66      0.68       156
#
#     accuracy                           0.79       476
#    macro avg       0.77      0.76      0.76       476
# weighted avg       0.79      0.79      0.79       476

# %% [markdown]
# <b>Classification report for ~360 components:</b>

# %%
# Training:

print(classification_report(y_train, y_predict_training_360))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       961
#            1       0.95      0.96      0.95       466
#
#     accuracy                           0.97      1427
#    macro avg       0.96      0.97      0.97      1427
# weighted avg       0.97      0.97      0.97      1427

# %%
# Testing:

print(classification_report(y_test, y_predict_test_360))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81       320
#            1       0.61      0.64      0.62       156
#
#     accuracy                           0.75       476
#    macro avg       0.72      0.72      0.72       476
# weighted avg       0.75      0.75      0.75       476

# %% [markdown]
# <b> Classification report for no PCA </b>

# %%
# Training:

print(classification_report(y_train, y_predict_training_full))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       961
#            1       1.00      1.00      1.00       466
#
#     accuracy                           1.00      1427
#    macro avg       1.00      1.00      1.00      1427
# weighted avg       1.00      1.00      1.00      1427

# %%
# Testing:

print(classification_report(y_test, y_predict_test_full))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       320
#            1       0.62      0.67      0.64       156
#
#     accuracy                           0.76       476
#    macro avg       0.73      0.73      0.73       476
# weighted avg       0.76      0.76      0.76       476

# %% [markdown]
# Notes: These all had similar test scores, and none of them did great at predicting death from cancer.
# </br>
# <b>F1 scores for predicting class 1 (cancer death):</b>
# * 190 components: 0.64
# * 360 components: 0.62
# * full data set: 0.64
#
# There is also significant overfitting happening, but less so with the 190 components. So far this is my favorite model.

# %% [markdown]
# ## 3.7 Exporting  <a id='3.7_export'></a>

# %%
''' these are the files I need to export, do so using pickle. 
X_train_190 
X_train_360 
X_train_full 

X_test_190 
X_test_360 
X_test_full 

'''
with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_train_190.pkl', 'wb') as file:
    pickle.dump(X_train_190, file)

with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_test_190.pkl', 'wb') as file:
    pickle.dump(X_test_190, file)
    
with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_train_360.pkl', 'wb') as file:
    pickle.dump(X_train_360, file)
    
with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_test_360.pkl', 'wb') as file:
    pickle.dump(X_test_190, file)
    
with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_train_full.pkl', 'wb') as file:
    pickle.dump(X_train_full, file)
    
with open(r'C:\Users\leann\OneDrive\Desktop\SPRINGBOARD\capstone 2\exports\X_test_full.pkl', 'wb') as file:
    pickle.dump(X_test_full, file)

# %% [markdown]
# ## 3.8 Summary & Next Steps <a id='3.8_summary'></a>
#
# In this notebook I did a test/train split on my numeric dataset, scaled it, and then performed PCA. I did PCA for 190 components, so as to prevent issues from being 'wide and short', and also for 360 components, which accounts for 90% of the variance in my dataset. I performed logistic regression on all 3 sets, and found that their performance metrics were similar. The F1 scores for accurately predicting death from cancer (1) for my test sets were all between 0.62-0.64, though I noted that there appears to be less overfitting with the set with 190 components.
#
# Next, I will do hyperparameter tuning and regularization to see if I can make an improved logistic regression model, and determine if F1 really is the best metric to judge our models on. I will also try other models on our data sets, including XG Boost, Random Forest Classifier, and LGBM Classifier.
#
# The next notebook is titled 'Capstone_2_modeling'
